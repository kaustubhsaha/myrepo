# %%
# the standard boilerplate stuff

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import spearmanr
from IPython.display import HTML, display
from pandas import Series, DataFrame

np.set_printoptions(threshold=np.nan)
pd.set_option('display.max_columns',500)

sns.set_style("white")

# %%
# turn off matplotlib interactive mode
plt.ioff()

# %% [markdown]
# A game of football has much more scope for analysis than the commonly used statistics like number of goals, number of cards etc. To analyze the events and their impact and also the betting stats, lets look at a secondary dataset.

# %%
events = pd.read_csv('events.csv')
display(HTML(events.head(2).to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id_odsp</th>
#       <th>id_event</th>
#       <th>sort_order</th>
#       <th>time</th>
#       <th>text</th>
#       <th>event_type</th>
#       <th>event_type2</th>
#       <th>side</th>
#       <th>event_team</th>
#       <th>opponent</th>
#       <th>player</th>
#       <th>player2</th>
#       <th>player_in</th>
#       <th>player_out</th>
#       <th>shot_place</th>
#       <th>shot_outcome</th>
#       <th>is_goal</th>
#       <th>location</th>
#       <th>bodypart</th>
#       <th>assist_method</th>
#       <th>situation</th>
#       <th>fast_break</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>UFot0hit/</td>
#       <td>UFot0hit1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>Attempt missed. Mladen Petric (Hamburg) left f...</td>
#       <td>1</td>
#       <td>12.0</td>
#       <td>2</td>
# ...

# %%
events.shape
# Out:
# (941009, 22)

# %% [markdown]
# So we have almost a million events in the dataset

# %% [markdown]
# We have one more file in the dataset. Lets look at it as well

# %%
ginf = pd.read_csv("ginf.csv")
display(HTML(ginf.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id_odsp</th>
#       <th>link_odsp</th>
#       <th>adv_stats</th>
#       <th>date</th>
#       <th>league</th>
#       <th>season</th>
#       <th>country</th>
#       <th>ht</th>
#       <th>at</th>
#       <th>fthg</th>
#       <th>ftag</th>
#       <th>odd_h</th>
#       <th>odd_d</th>
#       <th>odd_a</th>
#       <th>odd_over</th>
#       <th>odd_under</th>
#       <th>odd_bts</th>
#       <th>odd_bts_n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>UFot0hit/</td>
#       <td>/soccer/germany/bundesliga-2011-2012/dortmund-...</td>
#       <td>True</td>
#       <td>2011-08-05</td>
#       <td>D1</td>
#       <td>2012</td>
#       <td>germany</td>
#       <td>Borussia Dortmund</td>
#       <td>Hamburg SV</td>
#       <td>3</td>
#       <td>1</td>
#       <td>1.56</td>
#       <td>4.41</td>
#       <td>7.42</td>
# ...

# %%
ginf = ginf[['id_odsp', 'date', 'league', 'season','country','odd_h','odd_d','odd_a','fthg','ftag']]

# %%
ginf['prob_h']=1/1+ginf['odd_h']
ginf['prob_a']=1/1+ginf['odd_a']
ginf['prob_d']=1/1+ginf['odd_d']
ginf['pred_h_win']= ginf.apply(
    lambda row: 1 if (row['odd_h'] < row['odd_a']) else 0,
    axis=1
)
ginf['pred_a_win']= ginf.apply(
    lambda row: 1 if (row['odd_a'] < row['odd_h']) else 0,
    axis=1
)
ginf['pred_draw']= ginf.apply(
    lambda row: 1 if (row['odd_d'] < (row['odd_a']+row['odd_h'])/2) else 0,
    axis=1
)
ginf['h_win']= ginf.apply(
    lambda row: 1 if (row['fthg'] > row['ftag']) else 0,
    axis=1
)
ginf['a_win']= ginf.apply(
    lambda row: 1 if (row['fthg'] < row['ftag']) else 0,
    axis=1
)
ginf['draw']= ginf.apply(
    lambda row: 1 if (row['fthg'] == row['ftag']) else 0,
    axis=1
)

# %%
display(HTML(ginf.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id_odsp</th>
#       <th>date</th>
#       <th>league</th>
#       <th>season</th>
#       <th>country</th>
#       <th>odd_h</th>
#       <th>odd_d</th>
#       <th>odd_a</th>
#       <th>fthg</th>
#       <th>ftag</th>
#       <th>prob_h</th>
#       <th>prob_a</th>
#       <th>prob_d</th>
#       <th>pred_h_win</th>
#       <th>pred_a_win</th>
#       <th>pred_draw</th>
#       <th>h_win</th>
#       <th>a_win</th>
#       <th>draw</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>UFot0hit/</td>
#       <td>2011-08-05</td>
#       <td>D1</td>
#       <td>2012</td>
#       <td>germany</td>
#       <td>1.56</td>
#       <td>4.41</td>
#       <td>7.42</td>
#       <td>3</td>
#       <td>1</td>
#       <td>2.56</td>
#       <td>8.42</td>
#       <td>5.41</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
# ...

# %% [markdown]
# This dataset uses cryptic names like D1, F1 etc for the leagues. Lets replace the values to have the same set of names that we used in the original match result dataset

# %%
ginf.groupby(['league','country']).nunique()
# Out:
#                 id_odsp  date  league  season  country  odd_h  odd_d  odd_a  \
# league country
# D1     germany     1690   526       1       6        1    358    240    500
# E0     england     2120   553       1       6        1    358    227    498
# F1     france      2107   594       1       6        1    347    224    507
# I1     italy       2106   541       1       6        1    361    268    516
# SP1    spain       2089   681       1       6        1    390    304    572
#
#                 fthg  ftag  prob_h  prob_a  prob_d  pred_h_win  pred_a_win  \
# league country
# D1     germany    10     8     358     500     240           2           2
# E0     england     9     7     358     498     227           2           2
# F1     france      7     9     347     507     224           2           2
# I1     italy       8     8     361     516     268           2           2
# SP1    spain      11     9     390     572     304           2           2
#
# ...

# %% [markdown]
# So E0 means EPL, SP1 means La Liga, I1 means Serie A, F1 means Ligue1 and D1 means Bundesliga

# %%
league_map = {'E0': 'EPL', 'SP1': 'LaLiga','I1': 'SerieA', 'F1': 'Ligue1', 'D1': 'Bundesliga'}

# %%
ginf['league'] = ginf['league'].map(league_map)
ginf.groupby(['league','country']).nunique()
# Out:
#                     id_odsp  date  league  season  country  odd_h  odd_d  \
# league     country
# Bundesliga germany     1690   526       1       6        1    358    240
# EPL        england     2120   553       1       6        1    358    227
# LaLiga     spain       2089   681       1       6        1    390    304
# Ligue1     france      2107   594       1       6        1    347    224
# SerieA     italy       2106   541       1       6        1    361    268
#
#                     odd_a  fthg  ftag  prob_h  prob_a  prob_d  pred_h_win  \
# league     country
# Bundesliga germany    500    10     8     358     500     240           2
# EPL        england    498     9     7     358     498     227           2
# LaLiga     spain      572    11     9     390     572     304           2
# Ligue1     france     507     7     9     347     507     224           2
# SerieA     italy      516     8     8     361     516     268           2
#
# ...

# %% [markdown]
# Lets merge the two dataframes together

# %%
events = events.merge(ginf, how='left')
display(HTML(events.head(2).to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id_odsp</th>
#       <th>id_event</th>
#       <th>sort_order</th>
#       <th>time</th>
#       <th>text</th>
#       <th>event_type</th>
#       <th>event_type2</th>
#       <th>side</th>
#       <th>event_team</th>
#       <th>opponent</th>
#       <th>player</th>
#       <th>player2</th>
#       <th>player_in</th>
#       <th>player_out</th>
#       <th>shot_place</th>
#       <th>shot_outcome</th>
#       <th>is_goal</th>
#       <th>location</th>
#       <th>bodypart</th>
#       <th>assist_method</th>
#       <th>situation</th>
#       <th>fast_break</th>
#       <th>date</th>
#       <th>league</th>
#       <th>season</th>
#       <th>country</th>
#       <th>odd_h</th>
#       <th>odd_d</th>
#       <th>odd_a</th>
#       <th>fthg</th>
#       <th>ftag</th>
#       <th>prob_h</th>
#       <th>prob_a</th>
#       <th>prob_d</th>
#       <th>pred_h_win</th>
# ...

# %% [markdown]
# The data has a lot of columns with cryptic numeric values. Lets use the dictionary file to replace the cryptic values with meaningful data instead

# %%
event_type = {
    0:'Announcement',
    1:'Attempt',
    2:'Corner',
    3:'Foul',
    4:'Yellow card',
    5:'Second yellow card',
    6:'Red card',
    7:'Substitution',
    8:'Free kick won',
    9:'Offside',
    10:'Hand ball',
    11:'Penalty conceded'}

# %%
event_type2 = {12:'Key Pass', 13:'Failed through ball', 14:'Sending off', 15:'Own goal'}

# %%
events['event_type']=events['event_type'].map(event_type)
events['event_type2']=events['event_type2'].map(event_type2)

# %%
events['side']=events['side'].map({1:"Home",2:"Away"})

# %%
events['situation']=events['situation'].map({1:"Open play",2:"Set piece",3:"Corner",4:"Free kick"})

# %%
events['assist_method']=events['assist_method'].map({
    0:None,
    1:"Pass",
    2:"Cross",
    3:"Headed pass",
    4:"Through ball"
})

# %%
events['bodypart']=events['bodypart'].map({
    1:"right foot",
    2:"left foot",
    3:"head"

})

# %%
events['location']=events['location'].map({
    1:'Attacking half',
    2:'Defensive half',
    3:'Centre of the box',
    4:'Left wing',
    5:'Right wing',
    6:'Difficult angle and long range',
    7:'Difficult angle on the left',
    8:'Difficult angle on the right',
    9:'Left side of the box',
    10:'Left side of the six yard box',
    11:'Right side of the box',
    12:'Right side of the six yard box',
    13:'Very close range',
    14:'Penalty spot',
    15:'Outside the box',
    16:'Long range',
    17:'More than 35 yards',
    18:'More than 40 yards',
    19:'Not recorded'

})

# %%
events['shot_outcome']=events['shot_outcome'].map({
    1:'On target',
    2:'Off target',
    3:'Blocked',
    4:'Hit the bar'
})

# %%
events['shot_place']=events['shot_place'].map({
    1:'Bit too high',
	2:'Blocked',
	3:'Bottom left corner',
	4:'Bottom right corner',
	5:'Centre of the goal',
	6:'High and wide',
	7:'Hits the bar',
	8:'Misses to the left',
	9:'Misses to the right',
	10:'Too high',
	11:'Top centre of the goal',
	12:'Top left corner',
	13:'Top right corner'
})

# %%
events['season'] = events.apply(
    lambda row: str(row['season']-1) + "-"+ str(row['season']),
    axis=1
)

# %% [markdown]
# Lets look at the dataset once again now

# %%
display(HTML(events.head().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id_odsp</th>
#       <th>id_event</th>
#       <th>sort_order</th>
#       <th>time</th>
#       <th>text</th>
#       <th>event_type</th>
#       <th>event_type2</th>
#       <th>side</th>
#       <th>event_team</th>
#       <th>opponent</th>
#       <th>player</th>
#       <th>player2</th>
#       <th>player_in</th>
#       <th>player_out</th>
#       <th>shot_place</th>
#       <th>shot_outcome</th>
#       <th>is_goal</th>
#       <th>location</th>
#       <th>bodypart</th>
#       <th>assist_method</th>
#       <th>situation</th>
#       <th>fast_break</th>
#       <th>date</th>
#       <th>league</th>
#       <th>season</th>
#       <th>country</th>
#       <th>odd_h</th>
#       <th>odd_d</th>
#       <th>odd_a</th>
#       <th>fthg</th>
#       <th>ftag</th>
#       <th>prob_h</th>
#       <th>prob_a</th>
#       <th>prob_d</th>
#       <th>pred_h_win</th>
# ...

# %% [markdown]
# Now the event dataset is ready for analysis

# %% [markdown]
# Lets visualize the number of occurences for each type of event

# %%
plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = events['event_type'].value_counts().plot(kind='bar')
ax.set_ylim(0, 260000) 
ax.set_title('Frequency of events')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# Overall, the most frequent events are :
# 1. Free kick won
# 2. Foul
# 3. Attempt

# %% [markdown]
# Lets look at a league wise view of the number of events

# %% [markdown]
# a) <b> English Premier League </b>

# %%
plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
epl = events[events['league']=='EPL']
ax = epl['event_type'].value_counts().plot(kind='bar')
ax.set_ylim(0, 40000) 
ax.set_title('Frequency of events in EPL')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# Foul moves from no 2 to no 3 position. This is consistent with our observation from the previous dataset that EPL has lesser number of fouls.
#
# Attempt moves from no 3 to no 1 position. This is consistent with our observation from the other dataset that EPL has higher number of shots at goal as compared to other leagues

# %% [markdown]
# b) <b> La Liga </b>

# %%
plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
laliga = events[events['league']=='LaLiga']
ax = laliga['event_type'].value_counts().plot(kind='bar')
ax.set_ylim(0, 60000) 
ax.set_title('Frequency of events in La Liga')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# c) <b> Serie A </b>

# %%
plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
serieA = events[events['league']=='SerieA']
ax = serieA['event_type'].value_counts().plot(kind='bar')
ax.set_ylim(0, 65000) 
ax.set_title('Frequency of events in Serie A')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# d) <b> Bundesliga </b>

# %%
plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
bundesliga = events[events['league']=='Bundesliga']
ax = bundesliga['event_type'].value_counts().plot(kind='bar')
ax.set_ylim(0, 55000) 
ax.set_title('Frequency of events in Bundesliga')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# e) <b> Ligue One </b>

# %%
plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ligue1 = events[events['league']=='Ligue1']
ax = ligue1['event_type'].value_counts().plot(kind='bar')
ax.set_ylim(0, 60000) 
ax.set_title('Frequency of events in Ligue 1')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# So the top 3 events in every league are Free kick won, Fouls and Attempts. EPL witnesses almost half the number of Fouls as LaLiga even though both the leagues involve equal number of games per season

# %% [markdown]
# ## Where to shoot if you want to score a goal ?
#
# Lets look at the shots that resulted in goals

# %%
goals = events[(events['event_type'] == 'Attempt') & (events['is_goal'] == 1)]

# %%
plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = goals['shot_place'].value_counts().plot(kind='bar', rot=60)
ax.set_ylim(0, 8500) 
ax.set_title('Scoring shots ands their locations')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# The data suggests that its more effective to shoot at the bottom than to shoot at the top or centre

# %% [markdown]
# Lets have a look at the missed attempts as well

# %%
non_goals = events[(events['event_type'] == 'Attempt') & (events['is_goal'] == 0)]

# %%
plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
tmp = non_goals[non_goals['shot_place']!='Blocked']
ax = tmp['shot_place'].value_counts().plot(kind='bar', rot=60)
ax.set_ylim(0, 40000) 
ax.set_title('Missed shots and their locations')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# The number of saves in bottom left/right corner is quite low as opposed to centre of the box
#
# There are fewer saves at top left/right corner but the chances of missing are high (might hit the bar or may be too high)
#
# So, we can conclude that bottom right or left corners are the best locations to aim at while trying to score a goal

# %% [markdown]
# ## Which teams and players are the most prolific scorers ?
#
# Lets have a look at the most heavily scoring teams first

# %%
goals_grouping_by_team = goals.groupby('event_team')
goals_grouping_by_team = goals_grouping_by_team.count().sort_values(by='id_event', ascending=False)[:10]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = goals_grouping_by_team['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 650) 
ax.set_title('Most Goals Scored')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# Barcelona and Real Madrid are at the top. This is also in line with our observation that La Liga witnesses high number of goals.
#
# Interestingly none of the EPL teams make it to this list

# %% [markdown]
# Lets have a look at most prolific individual scorers now

# %%
goals_grouping_by_player = goals.groupby('player')
goals_grouping_by_player = goals_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:10]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = goals_grouping_by_player['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 250) 
ax.set_title('Most Goals Scored')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# No surprises there in the top two names !!!
#
# Zlatan Ibrahimovic is the only player to make it to this list after playing in three different leagues during this period

# %% [markdown]
# The players in the above chart might have high number of misses as well. Lets look at the players with maximum number of missed attempts

# %%
misses_grouping_by_player = non_goals.groupby('player')
misses_grouping_by_player = misses_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:10]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = misses_grouping_by_player['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 1100) 
ax.set_title('Most Shots missed')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# The top 3 are still Cristiano Ronaldo, Lionel Messi and Zlatan Ibrahimovic

# %% [markdown]
# Let's have a look at total number of Attempts as well

# %%
attempts = events[(events['event_type'] == 'Attempt') ]

# %%
attempts_grouping_by_player = attempts.groupby('player')
attempts_grouping_by_player = attempts_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:10]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = attempts_grouping_by_player['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 1300) 
ax.set_title('Most Shots Attempted')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# No wonder Christiano Ronaldo is considered as one of the greatest forwards of all time. He is almost 20 % ahead of Messi at second position

# %%
attempts_grouping_by_player = attempts.groupby('player')
attempts_grouping_by_player = attempts_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:100]
goals_grouping_by_player = goals.groupby('player')
goals_grouping_by_player = goals_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:100]
misses_grouping_by_player = non_goals.groupby('player')
misses_grouping_by_player = misses_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:100]

effectiveness_by_player = DataFrame({'total': attempts_grouping_by_player['id_event'].dropna(), 
                                     'is_goal': goals_grouping_by_player['id_event'].dropna(),
                                     'is_miss': misses_grouping_by_player['id_event'].dropna()})
effectiveness_by_player = effectiveness_by_player.sort_values('total', ascending=False)[:20]
plt.cla()
plt.clf()
f, ax = plt.subplots(figsize=(12, 8))
sns.set(style="darkgrid")
sns.set_color_codes("pastel")
sns.barplot(x="total",  y=effectiveness_by_player.index,
            data=effectiveness_by_player,
            label="# of attempts", color="b")
sns.set_color_codes("dark")
sns.barplot(x='is_miss',
            y=effectiveness_by_player.index, 
            data=effectiveness_by_player,
            label="# of misses", color="b")
sns.set_color_codes("muted")
sns.barplot(x='is_goal',
            y=effectiveness_by_player.index, 
            data=effectiveness_by_player,
            label="# of goals", color="b")
ax.legend(ncol=1, loc="lower right", frameon=True)
ax.set(ylabel="Players",
       xlabel="Number of goal attempts", title='Player effectiveness')

goal_scored = effectiveness_by_player['is_goal'].values
goal_attempts = effectiveness_by_player['total'].values
x_position = 50

for i in range(len(ax.patches[:20])):
    ax.text(ax.patches[i].get_width() - x_position, ax.patches[i].get_y() +.50, 
            str(round((goal_scored[i]/goal_attempts[i])*100, 2))+'%')
    
sns.despine(left=True, bottom=True)
f.tight_layout()
plt.show()

# %% [markdown]
# Clearly Christiano Ronaldo and Lionel Messi are considered among greatest off all times because they have been consistently creating chances.
#
# Their teammates like Suarez and Higuain have better attempt-to-goal-conversion-rate but doesn't create half as many chances as Messi and Ronaldo

# %%
sns.set(style="white")

# %% [markdown]
# ## Which teams and players commit the maximum number of fouls ?

# %%
fouls = events[(events['event_type'] == 'Foul') ]

# %%
fouls_grouping_by_team = fouls.groupby('event_team')
fouls_grouping_by_team = fouls_grouping_by_team.count().sort_values(by='id_event', ascending=False)[:15]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = fouls_grouping_by_team['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 4000) 
ax.set_title('Most Fouls Registered')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# More fouls are being committed by lower ranked teams in the league. Lyon and Lazio are the only top tier teams with very high number of fouls

# %%
fouls_grouping_by_player = fouls.groupby('player')
fouls_grouping_by_player = fouls_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:15]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = fouls_grouping_by_player['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 450) 
ax.set_title('Most Fouls Registered')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# Surprising to not see Sergio Ramos among top 15
#
# Lets look the card data as well, there should be some correlation between the two lists

# %%
cards = events[(events['event_type'] == 'Yellow card') | (events['event_type'] == 'Red card') | (events['event_type'] == 'Second yellow card')]
cards_grouping_by_player = cards.groupby('player')
cards_grouping_by_player = cards_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:15]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = cards_grouping_by_player['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 100) 
ax.set_title('Most Fouls Registered')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# Gabi from Athletico Madrid is among the worst offenders - he features in top 3 in terms of both the number of fouls committed as well as the number of cards

# %% [markdown]
# ## Which teams and players concede the maximum number of corners ?

# %%
corners = events[(events['event_type'] == 'Corner') ]

# %%
corners_grouping_by_team = corners.groupby('event_team')
corners_grouping_by_team = corners_grouping_by_team.count().sort_values(by='id_event', ascending=False)[:10]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = corners_grouping_by_team['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 1500) 
ax.set_title('Most Corners Conceded')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# The top 10 list is dominated by La Liga (Real Madrid, Barcelona, Athletico Madrid, Sevilla) and Serie A (Internazionale, AS Roma, Juventus, AC Milan, Napoli)
#
# So we can clearly conclude that teams in La Liga and Serie A concede more corners compared to other leagues

# %%
corners_grouping_by_player = corners.groupby('player')
corners_grouping_by_player = corners_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:10]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = corners_grouping_by_player['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 300) 
ax.set_title('Most Corners Conceded')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# ## Which players contribute the most through assists ?

# %%
assists = events[events['assist_method'].notnull()]

# %%
assists_grouping_by_player = assists.groupby('player')
assists_grouping_by_player = assists_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:10]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = assists_grouping_by_player['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 1000) 
ax.set_title('Most Assists Produced')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# Again we have the two usual suspects at the top. Cristiano Ronaldo tops the number of assists as well (and is ahead of Messi at no 2 by 30 %)
#
# Higuain and Benzema also appear in the top 10 list indicating that they played a significant role behind Christiano Ronaldo's success as a goalscorer

# %% [markdown]
# ## Messi vs Ronaldo - What does data indicate ?

# %% [markdown]
# Lets build a player comparator

# %%
def player_comparator(events, players):
    
    data = DataFrame(columns=['Goals','Misses','Attempts','Assists','Cards','Fouls','Offsides'],index = players)
    
    offsides_grouping_by_player = events[events['event_type']=='Offside'].groupby('player').count()
    attempts_grouping_by_player = attempts.groupby('player').count()
    misses_grouping_by_player = non_goals.groupby('player').count()
    goals_grouping_by_player = goals.groupby('player').count()
    assists_grouping_by_player = assists.groupby('player').count()
    cards_grouping_by_player = cards.groupby('player').count()
    fouls_grouping_by_player = fouls.groupby('player').count()
    
    build_feature(data, goals_grouping_by_player, 'Goals', players )
    build_feature(data, misses_grouping_by_player, 'Misses', players )
    build_feature(data, attempts_grouping_by_player, 'Attempts', players )
    build_feature(data, assists_grouping_by_player, 'Assists', players )
    build_feature(data, cards_grouping_by_player, 'Cards', players )
    build_feature(data, fouls_grouping_by_player, 'Fouls', players )
    build_feature(data, offsides_grouping_by_player, 'Offsides', players )
 
    return data

def build_feature(target, source, feature, players):
    for p in players:
        if (p in target.index):
            row = target.loc[p]
            row[feature]=source.loc[p]['id_odsp']

    
cmp = player_comparator(events, ['lionel messi','cristiano ronaldo','zlatan ibrahimovic','gonzalo higuain','luis suarez','karim benzema','gareth bale', 'harry kane','neymar'])
display(HTML(cmp.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Goals</th>
#       <th>Misses</th>
#       <th>Attempts</th>
#       <th>Assists</th>
#       <th>Cards</th>
#       <th>Fouls</th>
#       <th>Offsides</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>lionel messi</th>
#       <td>205</td>
#       <td>709</td>
#       <td>914</td>
#       <td>604</td>
#       <td>17</td>
#       <td>68</td>
#       <td>89</td>
#     </tr>
#     <tr>
#       <th>cristiano ronaldo</th>
#       <td>198</td>
#       <td>992</td>
#       <td>1190</td>
#       <td>862</td>
#       <td>29</td>
#       <td>100</td>
#       <td>206</td>
#     </tr>
#     <tr>
#       <th>zlatan ibrahimovic</th>
#       <td>153</td>
#       <td>621</td>
#       <td>774</td>
#       <td>487</td>
#       <td>29</td>
#       <td>248</td>
#       <td>225</td>
#     </tr>
#     <tr>
#       <th>gonzalo higuain</th>
#       <td>118</td>
# ...

# %% [markdown]
# ## When are the most goals scored during a football match ?

# %%
plt.cla()
plt.clf()

fig=plt.figure(figsize=(15,10))
plt.grid()

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)

plt.hist(goals[goals['side']=='Home']['time'], bins=100, label="Home team Goals", color='black', width=1)
plt.hist(goals[goals['side']=='Away']['time'], bins=100, label="Away team Goals", color='orange', width=1)

plt.xlabel("Time",fontsize=15)
plt.ylabel("# of Goals",fontsize=15)
plt.title("Goal distribution as a function of time",fontsize=20)
plt.legend(loc="best",fontsize=20)
plt.show()

# %% [markdown]
# Interestingly there's a massive spike in number of goals just before half time and full time

# %% [markdown]
# ## When do the most substitutions occur ?

# %%
substitutions = events[events['event_type']=='Substitution']
substitutions_by_time = substitutions['time'].value_counts()
substitutions_by_time = substitutions_by_time.sort_index()

# %%
plt.cla()
plt.clf()

fig=plt.figure(figsize=(15,10))
plt.grid()

#plt.hist(goals[goals['side']=='Home']['time'], bins=100, label="Home team Goals", color='black', width=1)
substitutions_by_time.plot(kind='bar')

plt.xlabel("Time",fontsize=15)
plt.ylabel("# of substitutions",fontsize=15)
plt.xticks([])
plt.title("# of substitutions as a function of time",fontsize=20)
plt.show()

# %% [markdown]
# There's a massive spike in number of substitutions at around half time
# More substitutions happen during the second half of a match which makes logical sense

# %% [markdown]
# ## When are the most number of red/yellow cards shown during a football match ?

# %%
red = events[events['event_type'] == 'Red card']
yellow = events[(events['event_type'] == 'Yellow card') | (events['event_type'] == 'Second yellow card')]

# %%
plt.cla()
plt.clf()

fig=plt.figure(figsize=(15,10))
plt.grid()

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)

plt.hist(yellow['time'], bins=100, label="Yellow Cards", color='yellow', width=1)
plt.hist(red['time'], bins=100, label="Red cards", color='red', width=1)

plt.xlabel("Time",fontsize=15)
plt.ylabel("# of Cards",fontsize=15)
plt.title("Card distribution as a function of time",fontsize=20)
plt.legend(loc="best",fontsize=20)
plt.show()

# %% [markdown]
# There's a spike in number of yellow cards just before half time and full time
# Most red cards are shown in last few minutes of a match (possibly when opponent is trailing by a goal and desperate to score and thus, the stakes are high) )

# %% [markdown]
# ## Which players provide the most number of early breakthroughs ?

# %% [markdown]
# For our analysis we'll consider a goal scored in first 10 minutes of a match as an early breakthrough

# %%
early_goals = goals[goals['time']<10]

# %%
early_goals_grouping_by_player = early_goals.groupby('player')
early_goals_grouping_by_player = early_goals_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:15]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = early_goals_grouping_by_player['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 20) 
ax.set_title('Most Early (<10 mins) Goals Scored')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# There are very few goals that are scored in first 10 minutes of a match. Real Madrid has 3 players in the top 5 list

# %% [markdown]
# Let's look the corresponding team data as well

# %%
early_goals_grouping_by_team = early_goals.groupby('event_team')
early_goals_grouping_by_team = early_goals_grouping_by_team.count().sort_values(by='id_event', ascending=False)[:15]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = early_goals_grouping_by_team['id_event'].plot(kind='bar', rot=60)
ax.set_ylim(0, 50)
ax.set_title('Most Early (<10 mins) Goals Scored')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# No surprises there. Real Madrid scores the maximum number of goals in first 10 minutes of a match

# %% [markdown]
# ## Which players tend to score the most during last few minutes ?

# %% [markdown]
# For this, we will only consider goals scored after 85 minutes

# %%
late_goals = goals[goals['time']>85]

# %%
late_goals_grouping_by_player = late_goals.groupby('player')
late_goals_grouping_by_player = late_goals_grouping_by_player.count().sort_values(by='id_event', ascending=False)[:15]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = late_goals_grouping_by_player['id_event'].plot(kind='bar')
ax.set_ylim(0, 25) 
ax.set_title('Most Late (>85 mins) Goals Scored')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# Again we have the same trio at top 3

# %% [markdown]
# Let's look at team level data as well

# %%
late_goals_grouping_by_team = late_goals.groupby('event_team')
late_goals_grouping_by_team = late_goals_grouping_by_team.count().sort_values(by='id_event', ascending=False)[:15]

plt.cla()
plt.clf()
f, axes = plt.subplots(1, 1 , figsize=(16,5))
ax = late_goals_grouping_by_team['id_event'].plot(kind='bar')
ax.set_ylim(0, 70) 
ax.set_title('Most Late (>85 mins) Goals Scored')
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
 
plt.show()

# %% [markdown]
# Just like early goals, Real Madrid leads in terms of number of late goals scored too

# %% [markdown]
# ## Whats the best league to bet if you are a rookie ?

# %% [markdown]
# Let's do a league-wise analysis

# %% [markdown]
# A. <b> EPL </b>

# %%
plt.cla()
plt.clf()

epl = events[events['league']=='EPL']
epl = epl[['pred_h_win','pred_a_win','pred_draw','h_win','a_win','draw']]
corr_matrix = epl.corr().round(2)
f = plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, center=0, annot=True, cmap='summer')
plt.title("EPL Correlation Matrix : Betting Odds vs Result")
plt.show()

# %% [markdown]
# The betting odds have the following correlation with the actual results: <br>
# a) Home Team Win : 0.38<br>
# b) Away Team Win : 0.37<br>
# c) Draw : 0.14

# %% [markdown]
# b) <b> La Liga </b>

# %%
plt.cla()
plt.clf()

laliga = events[events['league']=='LaLiga']
laliga = laliga[['pred_h_win','pred_a_win','pred_draw','h_win','a_win','draw']]
corr_matrix = laliga.corr().round(2)
f = plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, center=0, annot=True, cmap='summer')
plt.title("La Liga Correlation Matrix : Betting Odds vs Result")
plt.show()

# %% [markdown]
# The betting odds have the following correlation with the actual results: <br>
# a) Home Team Win : 0.41<br>
# b) Away Team Win : 0.38<br>
# c) Draw : 0.16

# %% [markdown]
# c) <b> Serie A </b>

# %%
plt.cla()
plt.clf()

serieA = events[events['league']=='SerieA']
serieA = serieA[['pred_h_win','pred_a_win','pred_draw','h_win','a_win','draw']]
corr_matrix = serieA.corr().round(2)
f = plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, center=0, annot=True, cmap='summer')
plt.title("Serie A Correlation Matrix : Betting Odds vs Result")
plt.show()

# %% [markdown]
# The betting odds have the following correlation with the actual results: <br>
# a) Home Team Win : 0.36<br>
# b) Away Team Win : 0.39<br>
# c) Draw : 0.1

# %% [markdown]
# d) <b> Bundesliga </b>

# %%
plt.cla()
plt.clf()

bundesliga = events[events['league']=='Bundesliga']
bundesliga = bundesliga[['pred_h_win','pred_a_win','pred_draw','h_win','a_win','draw']]
corr_matrix = bundesliga.corr().round(2)
f = plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, center=0, annot=True, cmap='summer')
plt.title("Bundesliga Correlation Matrix : Betting Odds vs Result")
plt.show()

# %% [markdown]
# The betting odds have the following correlation with the actual results: <br>
# a) Home Team Win : 0.32<br>
# b) Away Team Win : 0.32<br>
# c) Draw : 0.13

# %% [markdown]
# e) <b> Ligue One </b>

# %%
plt.cla()
plt.clf()

ligue1 = events[events['league']=='Ligue1']
ligue1 = ligue1[['pred_h_win','pred_a_win','pred_draw','h_win','a_win','draw']]
corr_matrix = ligue1.corr().round(2)
f = plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, center=0, annot=True, cmap='summer')
plt.title("Ligue One Correlation Matrix : Betting Odds vs Result")
plt.show()

# %% [markdown]
# The betting odds have the following correlation with the actual results: <br>
# a) Home Team Win : 0.3<br>
# b) Away Team Win : 0.33<br>
# c) Draw : 0.1

# %% [markdown]
# In general, the bookie odds are not a very good indicator of actual results
#
# The odds for draw are the worst
#
# Moral of the story : Dont rely on betting odds if you aim to get rich through betting !!

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# The next cell needs to be executed only once - the first time when you are running this on a particular host

# %%
# !pip install python-espncricinfo
# !pip install grequests
# !pip install pandas
# !pip install numpy
# Out:
# Requirement already satisfied: python-espncricinfo in c:\users\kaustubh\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: dateparser in c:\users\kaustubh\anaconda3\lib\site-packages (from python-espncricinfo) (0.7.1)
# Requirement already satisfied: bs4 in c:\users\kaustubh\anaconda3\lib\site-packages (from python-espncricinfo) (0.0.1)
# Requirement already satisfied: requests in c:\users\kaustubh\anaconda3\lib\site-packages (from python-espncricinfo) (2.21.0)
# Requirement already satisfied: regex in c:\users\kaustubh\anaconda3\lib\site-packages (from dateparser->python-espncricinfo) (2019.4.14)
# Requirement already satisfied: python-dateutil in c:\users\kaustubh\anaconda3\lib\site-packages (from dateparser->python-espncricinfo) (2.8.0)
# Requirement already satisfied: pytz in c:\users\kaustubh\anaconda3\lib\site-packages (from dateparser->python-espncricinfo) (2018.9)
# Requirement already satisfied: tzlocal in c:\users\kaustubh\anaconda3\lib\site-packages (from dateparser->python-espncricinfo) (1.5.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\kaustubh\anaconda3\lib\site-packages (from bs4->python-espncricinfo) (4.7.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\kaustubh\anaconda3\lib\site-packages (from requests->python-espncricinfo) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kaustubh\anaconda3\lib\site-packages (from requests->python-espncricinfo) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kaustubh\anaconda3\lib\site-packages (from requests->python-espncricinfo) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kaustubh\anaconda3\lib\site-packages (from requests->python-espncricinfo) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\kaustubh\anaconda3\lib\site-packages (from python-dateutil->dateparser->python-espncricinfo) (1.12.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\kaustubh\anaconda3\lib\site-packages (from beautifulsoup4->bs4->python-espncricinfo) (1.8)
# Requirement already satisfied: grequests in c:\users\kaustubh\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: requests in c:\users\kaustubh\anaconda3\lib\site-packages (from grequests) (2.21.0)
# Requirement already satisfied: gevent in c:\users\kaustubh\anaconda3\lib\site-packages (from grequests) (1.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kaustubh\anaconda3\lib\site-packages (from requests->grequests) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\kaustubh\anaconda3\lib\site-packages (from requests->grequests) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kaustubh\anaconda3\lib\site-packages (from requests->grequests) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kaustubh\anaconda3\lib\site-packages (from requests->grequests) (3.0.4)
# Requirement already satisfied: greenlet>=0.4.14 in c:\users\kaustubh\anaconda3\lib\site-packages (from gevent->grequests) (0.4.15)
# Requirement already satisfied: cffi>=1.11.5 in c:\users\kaustubh\anaconda3\lib\site-packages (from gevent->grequests) (1.12.2)
# Requirement already satisfied: pycparser in c:\users\kaustubh\anaconda3\lib\site-packages (from cffi>=1.11.5->gevent->grequests) (2.19)
# Requirement already satisfied: pandas in c:\users\kaustubh\anaconda3\lib\site-packages (0.24.2)
# Requirement already satisfied: pytz>=2011k in c:\users\kaustubh\anaconda3\lib\site-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\kaustubh\anaconda3\lib\site-packages (from pandas) (1.16.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\kaustubh\anaconda3\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\kaustubh\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)
# Requirement already satisfied: numpy in c:\users\kaustubh\anaconda3\lib\site-packages (1.16.2)

# %% [markdown]
# This will take a while:

# %%
from espncricinfo.summary import Summary
from espncricinfo.match import Match 
from espncricinfo.series import Series
from espncricinfo.exceptions import MatchNotFoundError, NoScorecardError

# %%
from bs4 import BeautifulSoup

# %%
import json
import requests

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Get a match id as import from user. Match id is a numeric value (e.g 1178415) used by espncricinfo as unique identifier for a match

# %%
match_id = input("Please enter match id :")
# Out:
# Please enter match id :1178411

# %% [markdown]
# Based on the match_id, generate the scorecard URL

# %%
url = Match(match_id).match_url
print("Will extract match details from ", url)
# Out:
# Will extract match details from  http://www.espncricinfo.com/matches/engine/match/1178411.html

# %%
match_html = Match(match_id).html

# %%
match_json = json.loads(match_html.find_all('script')[12].get_text().replace("\n", " ").replace('window.__INITIAL_STATE__ =','').replace('&dagger;','wk').replace('&amp;','').replace('wkts;','wkts,').replace('wkt;','wkt,').strip().replace('};', "}};").split('};')[0])

# %%
batting_innings_1 = pd.DataFrame(match_json['gamePackage']['scorecard']['innings']['1']['batsmen'])
batting_innings_1.head()
# Out:
#    captain                                         commentary  hasVideoId  \
# 0    False  wrong'un, short one, pitching on off stump and...       False
# 1     True  <B>straight back to the bowler!</b> Bit of an ...       False
# 2    False  there's the answer. Dhawal Kulkarni's on the f...       False
# 3    False  well, we have a review for lbw first ball! Yor...       False
# 4    False  got him, huge wicket. Another slower cutter, a...       False
#
#                                                 href  isNotOut        name  \
# 0  http://www.espncricinfo.com/ci/content/player/...     False   Q de Kock
# 1  http://www.espncricinfo.com/ci/content/player/...     False   RG Sharma
# 2  http://www.espncricinfo.com/ci/content/player/...     False    SA Yadav
# 3  http://www.espncricinfo.com/ci/content/player/...     False   HH Pandya
# 4  http://www.espncricinfo.com/ci/content/player/...     False  KA Pollard
#
#   roles      runningOver                 runningScore           shortText  \
# 0    wk  {'overs': 14.3}  {'wickets': 3, 'runs': 111}    c Stokes b Gopal
# 1   (c)   {'overs': 2.3}   {'wickets': 1, 'runs': 11}          c  b Gopal
# 2        {'overs': 13.5}  {'wickets': 2, 'runs': 108}  c Kulkarni b Binny
# 3        {'overs': 19.1}  {'wickets': 5, 'runs': 152}        lbw b Archer
# 4        {'overs': 16.5}  {'wickets': 4, 'runs': 124}           b Unadkat
#
#                                                stats  \
# 0  [{'name': 'runs', 'text': 'R', 'value': '65'},...
# 1  [{'name': 'runs', 'text': 'R', 'value': '5'}, ...
# 2  [{'name': 'runs', 'text': 'R', 'value': '34'},...
# 3  [{'name': 'runs', 'text': 'R', 'value': '23'},...
# 4  [{'name': 'runs', 'text': 'R', 'value': '10'},...
#
#                           trackingName
# 0  &lpos=cricket:game:scorecard:player
# 1  &lpos=cricket:game:scorecard:player
# 2  &lpos=cricket:game:scorecard:player
# 3  &lpos=cricket:game:scorecard:player
# 4  &lpos=cricket:game:scorecard:player

# %%
bat1_label = match_json['gamePackage']['scorecard']['innings']['1']['title']
bat1_label_splits = bat1_label.split(' ')
bat1_label_splits.pop()
bat1_team =  " ".join(bat1_label_splits)
print(bat1_team, "batted first")
# Out:
# Mumbai Indians batted first

# %%
batting_innings_2 = pd.DataFrame(match_json['gamePackage']['scorecard']['innings']['2']['batsmen'])
batting_innings_2.head()
# Out:
#    captain                                         commentary  hasVideoId  \
# 0    False  <b>caught at cover!</b> Chahar hits back. Full...       False
# 1    False  <B>caught at long-on!</b> It was all looking s...       False
# 2     True                                                          False
# 3    False  <b>dragged on!</b> A gamechanging over? Not th...       False
# 4    False  length ball angling into off stump, clipped aw...       False
#
#                                                 href  isNotOut       name  \
# 0  http://www.espncricinfo.com/ci/content/player/...     False  AM Rahane
# 1  http://www.espncricinfo.com/ci/content/player/...     False  SV Samson
# 2  http://www.espncricinfo.com/ci/content/player/...      True  SPD Smith
# 3  http://www.espncricinfo.com/ci/content/player/...     False  BA Stokes
# 4  http://www.espncricinfo.com/ci/content/player/...     False    R Parag
#
#   roles      runningOver                 runningScore  \
# 0         {'overs': 3.4}   {'wickets': 1, 'runs': 39}
# 1    wk   {'overs': 7.2}   {'wickets': 2, 'runs': 76}
# 2   (c)               {}                           {}
# 3         {'overs': 7.6}   {'wickets': 3, 'runs': 77}
# 4        {'overs': 17.4}  {'wickets': 4, 'runs': 147}
#
#                   shortText  \
# 0          c Yadav b Chahar
# 1        c Pollard b Chahar
# 2                   not out
# 3                  b Chahar
# 4  run out (Cutting/Pandya)
#
#                                                stats  \
# 0  [{'name': 'runs', 'text': 'R', 'value': '12'},...
# 1  [{'name': 'runs', 'text': 'R', 'value': '35'},...
# 2  [{'name': 'runs', 'text': 'R', 'value': '59'},...
# 3  [{'name': 'runs', 'text': 'R', 'value': '0'}, ...
# 4  [{'name': 'runs', 'text': 'R', 'value': '43'},...
#
#                           trackingName
# 0  &lpos=cricket:game:scorecard:player
# 1  &lpos=cricket:game:scorecard:player
# 2  &lpos=cricket:game:scorecard:player
# 3  &lpos=cricket:game:scorecard:player
# 4  &lpos=cricket:game:scorecard:player

# %%
bat2_label = match_json['gamePackage']['scorecard']['innings']['2']['title']
bat2_label_splits = bat2_label.split(' ')
bat2_label_splits.pop()
bat2_team =  " ".join(bat2_label_splits)
print(bat2_team, "batted second")
# Out:
# Rajasthan Royals batted second

# %%
batting_innings_1['Team'] = bat1_team
batting_innings_1['Opponent'] = bat2_team
batting_innings_2['Team'] = bat2_team
batting_innings_2['Opponent'] = bat1_team

# %%
def flatten(js):
    return pd.DataFrame(js).set_index(['text','name']).squeeze()

# %% [markdown]
# Extract batting stats for batting innings 1

# %%
batting_innings_1_stats = batting_innings_1.stats.apply(flatten)
batting_innings_1_stats
# Out:
# text    R          B       M    4s    6s         SR
# name runs ballsFaced minutes fours sixes strikeRate
# 0      65         47      74     6     2     138.29
# 1       5          7      13     1     0      71.42
# 2      34         33      58     1     1     103.03
# 3      23         15      37     2     1     153.33
# 4      10          7      16     0     1     142.85
# 5      13          9      20     1     1     144.44
# 6       2          2       4     0     0     100.00

# %% [markdown]
# Extract batting stats for batting innings 2

# %%
batting_innings_2_stats = batting_innings_1.stats.apply(flatten)
batting_innings_2_stats
# Out:
# text    R          B       M    4s    6s         SR
# name runs ballsFaced minutes fours sixes strikeRate
# 0      65         47      74     6     2     138.29
# 1       5          7      13     1     0      71.42
# 2      34         33      58     1     1     103.03
# 3      23         15      37     2     1     153.33
# 4      10          7      16     0     1     142.85
# 5      13          9      20     1     1     144.44
# 6       2          2       4     0     0     100.00

# %%
def remove_extra_cols_bat(df):
    if df.columns.contains('captain'):
        df = df.drop(['captain','commentary','runningScore','runningOver', 'stats','hasVideoId','href','roles','trackingName'], axis=1)
    return df

# %%
batting_innings_1 = remove_extra_cols_bat(batting_innings_1)
batting_innings_2 = remove_extra_cols_bat(batting_innings_2)

# %%
batting_innings_1
# Out:
#    isNotOut         name           shortText            Team          Opponent
# 0     False    Q de Kock    c Stokes b Gopal  Mumbai Indians  Rajasthan Royals
# 1     False    RG Sharma          c  b Gopal  Mumbai Indians  Rajasthan Royals
# 2     False     SA Yadav  c Kulkarni b Binny  Mumbai Indians  Rajasthan Royals
# 3     False    HH Pandya        lbw b Archer  Mumbai Indians  Rajasthan Royals
# 4     False   KA Pollard           b Unadkat  Mumbai Indians  Rajasthan Royals
# 5      True  BCJ Cutting             not out  Mumbai Indians  Rajasthan Royals
# 6      True    KH Pandya             not out  Mumbai Indians  Rajasthan Royals

# %%
batting_innings_2
# Out:
#    isNotOut       name                 shortText              Team  \
# 0     False  AM Rahane          c Yadav b Chahar  Rajasthan Royals
# 1     False  SV Samson        c Pollard b Chahar  Rajasthan Royals
# 2      True  SPD Smith                   not out  Rajasthan Royals
# 3     False  BA Stokes                  b Chahar  Rajasthan Royals
# 4     False    R Parag  run out (Cutting/Pandya)  Rajasthan Royals
# 5     False  AJ Turner              lbw b Bumrah  Rajasthan Royals
# 6      True  STR Binny                   not out  Rajasthan Royals
#
#          Opponent
# 0  Mumbai Indians
# 1  Mumbai Indians
# 2  Mumbai Indians
# 3  Mumbai Indians
# 4  Mumbai Indians
# 5  Mumbai Indians
# 6  Mumbai Indians

# %%
full_batting_innings_1 = pd.concat([batting_innings_1, batting_innings_1_stats], axis=1)
full_batting_innings_1 = full_batting_innings_1.dropna()
full_batting_innings_1
# Out:
#    isNotOut         name           shortText            Team  \
# 0     False    Q de Kock    c Stokes b Gopal  Mumbai Indians
# 1     False    RG Sharma          c  b Gopal  Mumbai Indians
# 2     False     SA Yadav  c Kulkarni b Binny  Mumbai Indians
# 3     False    HH Pandya        lbw b Archer  Mumbai Indians
# 4     False   KA Pollard           b Unadkat  Mumbai Indians
# 5      True  BCJ Cutting             not out  Mumbai Indians
# 6      True    KH Pandya             not out  Mumbai Indians
#
#            Opponent (R, runs) (B, ballsFaced) (M, minutes) (4s, fours)  \
# 0  Rajasthan Royals        65              47           74           6
# 1  Rajasthan Royals         5               7           13           1
# 2  Rajasthan Royals        34              33           58           1
# 3  Rajasthan Royals        23              15           37           2
# 4  Rajasthan Royals        10               7           16           0
# 5  Rajasthan Royals        13               9           20           1
# 6  Rajasthan Royals         2               2            4           0
#
#   (6s, sixes) (SR, strikeRate)
# 0           2           138.29
# 1           0            71.42
# 2           1           103.03
# 3           1           153.33
# 4           1           142.85
# 5           1           144.44
# 6           0           100.00

# %%
full_batting_innings_2 = pd.concat([batting_innings_2, batting_innings_2_stats], axis=1)
full_batting_innings_2 = full_batting_innings_2.dropna()
full_batting_innings_2
# Out:
#    isNotOut       name                 shortText              Team  \
# 0     False  AM Rahane          c Yadav b Chahar  Rajasthan Royals
# 1     False  SV Samson        c Pollard b Chahar  Rajasthan Royals
# 2      True  SPD Smith                   not out  Rajasthan Royals
# 3     False  BA Stokes                  b Chahar  Rajasthan Royals
# 4     False    R Parag  run out (Cutting/Pandya)  Rajasthan Royals
# 5     False  AJ Turner              lbw b Bumrah  Rajasthan Royals
# 6      True  STR Binny                   not out  Rajasthan Royals
#
#          Opponent (R, runs) (B, ballsFaced) (M, minutes) (4s, fours)  \
# 0  Mumbai Indians        65              47           74           6
# 1  Mumbai Indians         5               7           13           1
# 2  Mumbai Indians        34              33           58           1
# 3  Mumbai Indians        23              15           37           2
# 4  Mumbai Indians        10               7           16           0
# 5  Mumbai Indians        13               9           20           1
# 6  Mumbai Indians         2               2            4           0
#
#   (6s, sixes) (SR, strikeRate)
# 0           2           138.29
# 1           0            71.42
# 2           1           103.03
# 3           1           153.33
# 4           1           142.85
# 5           1           144.44
# 6           0           100.00

# %%
batting = pd.concat([full_batting_innings_1, full_batting_innings_2], axis=0)
batting
# Out:
#    isNotOut         name                 shortText              Team  \
# 0     False    Q de Kock          c Stokes b Gopal    Mumbai Indians
# 1     False    RG Sharma                c  b Gopal    Mumbai Indians
# 2     False     SA Yadav        c Kulkarni b Binny    Mumbai Indians
# 3     False    HH Pandya              lbw b Archer    Mumbai Indians
# 4     False   KA Pollard                 b Unadkat    Mumbai Indians
# 5      True  BCJ Cutting                   not out    Mumbai Indians
# 6      True    KH Pandya                   not out    Mumbai Indians
# 0     False    AM Rahane          c Yadav b Chahar  Rajasthan Royals
# 1     False    SV Samson        c Pollard b Chahar  Rajasthan Royals
# 2      True    SPD Smith                   not out  Rajasthan Royals
# 3     False    BA Stokes                  b Chahar  Rajasthan Royals
# 4     False      R Parag  run out (Cutting/Pandya)  Rajasthan Royals
# 5     False    AJ Turner              lbw b Bumrah  Rajasthan Royals
# 6      True    STR Binny                   not out  Rajasthan Royals
#
#            Opponent (R, runs) (B, ballsFaced) (M, minutes) (4s, fours)  \
# 0  Rajasthan Royals        65              47           74           6
# 1  Rajasthan Royals         5               7           13           1
# 2  Rajasthan Royals        34              33           58           1
# 3  Rajasthan Royals        23              15           37           2
# 4  Rajasthan Royals        10               7           16           0
# 5  Rajasthan Royals        13               9           20           1
# 6  Rajasthan Royals         2               2            4           0
# 0    Mumbai Indians        65              47           74           6
# 1    Mumbai Indians         5               7           13           1
# 2    Mumbai Indians        34              33           58           1
# 3    Mumbai Indians        23              15           37           2
# 4    Mumbai Indians        10               7           16           0
# 5    Mumbai Indians        13               9           20           1
# 6    Mumbai Indians         2               2            4           0
#
#   (6s, sixes) (SR, strikeRate)
# 0           2           138.29
# 1           0            71.42
# 2           1           103.03
# 3           1           153.33
# 4           1           142.85
# 5           1           144.44
# 6           0           100.00
# 0           2           138.29
# 1           0            71.42
# 2           1           103.03
# 3           1           153.33
# 4           1           142.85
# 5           1           144.44
# 6           0           100.00

# %% [markdown]
# Tidy up the column names

# %%
batting.columns = ["isNotOut","name","out","team","opponent","runs","balls","mins","fours","sixes","strikeRate"]
batting
# Out:
#    isNotOut         name                       out              team  \
# 0     False    Q de Kock          c Stokes b Gopal    Mumbai Indians
# 1     False    RG Sharma                c  b Gopal    Mumbai Indians
# 2     False     SA Yadav        c Kulkarni b Binny    Mumbai Indians
# 3     False    HH Pandya              lbw b Archer    Mumbai Indians
# 4     False   KA Pollard                 b Unadkat    Mumbai Indians
# 5      True  BCJ Cutting                   not out    Mumbai Indians
# 6      True    KH Pandya                   not out    Mumbai Indians
# 0     False    AM Rahane          c Yadav b Chahar  Rajasthan Royals
# 1     False    SV Samson        c Pollard b Chahar  Rajasthan Royals
# 2      True    SPD Smith                   not out  Rajasthan Royals
# 3     False    BA Stokes                  b Chahar  Rajasthan Royals
# 4     False      R Parag  run out (Cutting/Pandya)  Rajasthan Royals
# 5     False    AJ Turner              lbw b Bumrah  Rajasthan Royals
# 6      True    STR Binny                   not out  Rajasthan Royals
#
#            opponent runs balls mins fours sixes strikeRate
# 0  Rajasthan Royals   65    47   74     6     2     138.29
# 1  Rajasthan Royals    5     7   13     1     0      71.42
# 2  Rajasthan Royals   34    33   58     1     1     103.03
# 3  Rajasthan Royals   23    15   37     2     1     153.33
# 4  Rajasthan Royals   10     7   16     0     1     142.85
# 5  Rajasthan Royals   13     9   20     1     1     144.44
# 6  Rajasthan Royals    2     2    4     0     0     100.00
# 0    Mumbai Indians   65    47   74     6     2     138.29
# 1    Mumbai Indians    5     7   13     1     0      71.42
# 2    Mumbai Indians   34    33   58     1     1     103.03
# 3    Mumbai Indians   23    15   37     2     1     153.33
# 4    Mumbai Indians   10     7   16     0     1     142.85
# 5    Mumbai Indians   13     9   20     1     1     144.44
# 6    Mumbai Indians    2     2    4     0     0     100.00

# %%
bowling_innings_1 = pd.DataFrame(match_json['gamePackage']['scorecard']['innings']['1']['bowlers'])
bowling_innings_1
# Out:
#    captain  hasVideoId                                               href  \
# 0    False       False  http://www.espncricinfo.com/ci/content/player/...
# 1    False       False  http://www.espncricinfo.com/ci/content/player/...
# 2    False       False  http://www.espncricinfo.com/ci/content/player/...
# 3    False       False  http://www.espncricinfo.com/ci/content/player/...
# 4    False       False  http://www.espncricinfo.com/ci/content/player/...
# 5    False       False  http://www.espncricinfo.com/ci/content/player/...
#
#           name roles                                              stats  \
# 0    STR Binny        [{'name': 'overs', 'text': 'O', 'value': '3'},...
# 1  DS Kulkarni        [{'name': 'overs', 'text': 'O', 'value': '3'},...
# 2      S Gopal        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 3    JC Archer        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 4   JD Unadkat        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 5      R Parag        [{'name': 'overs', 'text': 'O', 'value': '2'},...
#
#                           trackingName
# 0  &lpos=cricket:game:scorecard:player
# 1  &lpos=cricket:game:scorecard:player
# 2  &lpos=cricket:game:scorecard:player
# 3  &lpos=cricket:game:scorecard:player
# 4  &lpos=cricket:game:scorecard:player
# 5  &lpos=cricket:game:scorecard:player

# %%
bowling_innings_2 = pd.DataFrame(match_json['gamePackage']['scorecard']['innings']['2']['bowlers'])
bowling_innings_2
# Out:
#    captain  hasVideoId                                               href  \
# 0    False       False  http://www.espncricinfo.com/ci/content/player/...
# 1    False       False  http://www.espncricinfo.com/ci/content/player/...
# 2    False       False  http://www.espncricinfo.com/ci/content/player/...
# 3    False       False  http://www.espncricinfo.com/ci/content/player/...
# 4    False       False  http://www.espncricinfo.com/ci/content/player/...
# 5    False       False  http://www.espncricinfo.com/ci/content/player/...
#
#          name roles                                              stats  \
# 0   HH Pandya        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 1   KH Pandya        [{'name': 'overs', 'text': 'O', 'value': '2'},...
# 2  SL Malinga        [{'name': 'overs', 'text': 'O', 'value': '3.1'...
# 3   RD Chahar        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 4   JJ Bumrah        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 5  M Markande        [{'name': 'overs', 'text': 'O', 'value': '2'},...
#
#                           trackingName
# 0  &lpos=cricket:game:scorecard:player
# 1  &lpos=cricket:game:scorecard:player
# 2  &lpos=cricket:game:scorecard:player
# 3  &lpos=cricket:game:scorecard:player
# 4  &lpos=cricket:game:scorecard:player
# 5  &lpos=cricket:game:scorecard:player

# %%
bowling_innings_1['Team'] = bat2_team
bowling_innings_1['Opponent'] = bat1_team
bowling_innings_2['Team'] = bat1_team
bowling_innings_2['Opponent'] = bat2_team

# %%
bowling_innings_1_stats = bowling_innings_1.stats.apply(flatten)
bowling_innings_1_stats
# Out:
# text     O       M        R       W        Econ   0s            4s  \
# name overs maidens conceded wickets economyRate dots foursConceded
# 0        3       0       19       1        6.33    8             2
# 1        3       0       31       0       10.33    6             4
# 2        4       0       21       2        5.25    8             1
# 3        4       0       22       1        5.50   14             2
# 4        4       0       46       1       11.50    6             2
# 5        2       0       17       0        8.50    2             0
#
# text            6s    WD      NB
# name sixesConceded wides noballs
# 0                0     0       0
# 1                1     1       0
# 2                0     0       0
# 3                1     0       0
# 4                3     3       0
# 5                1     0       0

# %%
bowling_innings_2_stats = bowling_innings_2.stats.apply(flatten)
bowling_innings_2_stats
# Out:
# text     O       M        R       W        Econ   0s            4s  \
# name overs maidens conceded wickets economyRate dots foursConceded
# 0        4       0       31       0        7.75   10             5
# 1        2       0       24       0       12.00    1             4
# 2      3.1       0       27       0        8.52    6             4
# 3        4       0       29       3        7.25   10             3
# 4        4       0       21       1        5.25    8             1
# 5        2       0       24       0       12.00    4             2
#
# text            6s    WD      NB
# name sixesConceded wides noballs
# 0                0     0       0
# 1                0     0       0
# 2                0     0       0
# 3                1     0       0
# 4                0     0       0
# 5                2     0       0

# %%
def remove_extra_cols_bowl(df):
    if df.columns.contains('captain'):
        df = df.drop(['captain','stats','hasVideoId','href','roles','trackingName'], axis=1)
    return df

# %%
bowling_innings_1 = remove_extra_cols_bowl(bowling_innings_1)
bowling_innings_2 = remove_extra_cols_bowl(bowling_innings_2)

# %%
bowling_innings_1
# Out:
#           name              Team        Opponent
# 0    STR Binny  Rajasthan Royals  Mumbai Indians
# 1  DS Kulkarni  Rajasthan Royals  Mumbai Indians
# 2      S Gopal  Rajasthan Royals  Mumbai Indians
# 3    JC Archer  Rajasthan Royals  Mumbai Indians
# 4   JD Unadkat  Rajasthan Royals  Mumbai Indians
# 5      R Parag  Rajasthan Royals  Mumbai Indians

# %%
bowling_innings_2
# Out:
#          name            Team          Opponent
# 0   HH Pandya  Mumbai Indians  Rajasthan Royals
# 1   KH Pandya  Mumbai Indians  Rajasthan Royals
# 2  SL Malinga  Mumbai Indians  Rajasthan Royals
# 3   RD Chahar  Mumbai Indians  Rajasthan Royals
# 4   JJ Bumrah  Mumbai Indians  Rajasthan Royals
# 5  M Markande  Mumbai Indians  Rajasthan Royals

# %%
full_bowling_innings_1 = pd.concat([bowling_innings_1, bowling_innings_1_stats], axis=1)
full_bowling_innings_1 = full_bowling_innings_1.dropna()
full_bowling_innings_1
# Out:
#           name              Team        Opponent (O, overs) (M, maidens)  \
# 0    STR Binny  Rajasthan Royals  Mumbai Indians          3            0
# 1  DS Kulkarni  Rajasthan Royals  Mumbai Indians          3            0
# 2      S Gopal  Rajasthan Royals  Mumbai Indians          4            0
# 3    JC Archer  Rajasthan Royals  Mumbai Indians          4            0
# 4   JD Unadkat  Rajasthan Royals  Mumbai Indians          4            0
# 5      R Parag  Rajasthan Royals  Mumbai Indians          2            0
#
#   (R, conceded) (W, wickets) (Econ, economyRate) (0s, dots)  \
# 0            19            1                6.33          8
# 1            31            0               10.33          6
# 2            21            2                5.25          8
# 3            22            1                5.50         14
# 4            46            1               11.50          6
# 5            17            0                8.50          2
#
#   (4s, foursConceded) (6s, sixesConceded) (WD, wides) (NB, noballs)
# 0                   2                   0           0             0
# 1                   4                   1           1             0
# 2                   1                   0           0             0
# 3                   2                   1           0             0
# 4                   2                   3           3             0
# 5                   0                   1           0             0

# %%
full_bowling_innings_2 = pd.concat([bowling_innings_2, bowling_innings_2_stats], axis=1)
full_bowling_innings_2 = full_bowling_innings_2.dropna()
full_bowling_innings_2
# Out:
#          name            Team          Opponent (O, overs) (M, maidens)  \
# 0   HH Pandya  Mumbai Indians  Rajasthan Royals          4            0
# 1   KH Pandya  Mumbai Indians  Rajasthan Royals          2            0
# 2  SL Malinga  Mumbai Indians  Rajasthan Royals        3.1            0
# 3   RD Chahar  Mumbai Indians  Rajasthan Royals          4            0
# 4   JJ Bumrah  Mumbai Indians  Rajasthan Royals          4            0
# 5  M Markande  Mumbai Indians  Rajasthan Royals          2            0
#
#   (R, conceded) (W, wickets) (Econ, economyRate) (0s, dots)  \
# 0            31            0                7.75         10
# 1            24            0               12.00          1
# 2            27            0                8.52          6
# 3            29            3                7.25         10
# 4            21            1                5.25          8
# 5            24            0               12.00          4
#
#   (4s, foursConceded) (6s, sixesConceded) (WD, wides) (NB, noballs)
# 0                   5                   0           0             0
# 1                   4                   0           0             0
# 2                   4                   0           0             0
# 3                   3                   1           0             0
# 4                   1                   0           0             0
# 5                   2                   2           0             0

# %%
bowling = pd.concat([full_bowling_innings_1, full_bowling_innings_2], axis=0)
bowling
# Out:
#           name              Team          Opponent (O, overs) (M, maidens)  \
# 0    STR Binny  Rajasthan Royals    Mumbai Indians          3            0
# 1  DS Kulkarni  Rajasthan Royals    Mumbai Indians          3            0
# 2      S Gopal  Rajasthan Royals    Mumbai Indians          4            0
# 3    JC Archer  Rajasthan Royals    Mumbai Indians          4            0
# 4   JD Unadkat  Rajasthan Royals    Mumbai Indians          4            0
# 5      R Parag  Rajasthan Royals    Mumbai Indians          2            0
# 0    HH Pandya    Mumbai Indians  Rajasthan Royals          4            0
# 1    KH Pandya    Mumbai Indians  Rajasthan Royals          2            0
# 2   SL Malinga    Mumbai Indians  Rajasthan Royals        3.1            0
# 3    RD Chahar    Mumbai Indians  Rajasthan Royals          4            0
# 4    JJ Bumrah    Mumbai Indians  Rajasthan Royals          4            0
# 5   M Markande    Mumbai Indians  Rajasthan Royals          2            0
#
#   (R, conceded) (W, wickets) (Econ, economyRate) (0s, dots)  \
# 0            19            1                6.33          8
# 1            31            0               10.33          6
# 2            21            2                5.25          8
# 3            22            1                5.50         14
# 4            46            1               11.50          6
# 5            17            0                8.50          2
# 0            31            0                7.75         10
# 1            24            0               12.00          1
# 2            27            0                8.52          6
# 3            29            3                7.25         10
# 4            21            1                5.25          8
# 5            24            0               12.00          4
#
#   (4s, foursConceded) (6s, sixesConceded) (WD, wides) (NB, noballs)
# 0                   2                   0           0             0
# 1                   4                   1           1             0
# 2                   1                   0           0             0
# 3                   2                   1           0             0
# 4                   2                   3           3             0
# 5                   0                   1           0             0
# 0                   5                   0           0             0
# 1                   4                   0           0             0
# 2                   4                   0           0             0
# 3                   3                   1           0             0
# 4                   1                   0           0             0
# 5                   2                   2           0             0

# %% [markdown]
# Tidy up the column names

# %%
bowling.columns = ['name','team','opponent','overs','maidens','conceded','wickets','economy','dots','fours','sixes','wides','noballs']
bowling
# Out:
#           name              team          opponent overs maidens conceded  \
# 0    STR Binny  Rajasthan Royals    Mumbai Indians     3       0       19
# 1  DS Kulkarni  Rajasthan Royals    Mumbai Indians     3       0       31
# 2      S Gopal  Rajasthan Royals    Mumbai Indians     4       0       21
# 3    JC Archer  Rajasthan Royals    Mumbai Indians     4       0       22
# 4   JD Unadkat  Rajasthan Royals    Mumbai Indians     4       0       46
# 5      R Parag  Rajasthan Royals    Mumbai Indians     2       0       17
# 0    HH Pandya    Mumbai Indians  Rajasthan Royals     4       0       31
# 1    KH Pandya    Mumbai Indians  Rajasthan Royals     2       0       24
# 2   SL Malinga    Mumbai Indians  Rajasthan Royals   3.1       0       27
# 3    RD Chahar    Mumbai Indians  Rajasthan Royals     4       0       29
# 4    JJ Bumrah    Mumbai Indians  Rajasthan Royals     4       0       21
# 5   M Markande    Mumbai Indians  Rajasthan Royals     2       0       24
#
#   wickets economy dots fours sixes wides noballs
# 0       1    6.33    8     2     0     0       0
# 1       0   10.33    6     4     1     1       0
# 2       2    5.25    8     1     0     0       0
# 3       1    5.50   14     2     1     0       0
# 4       1   11.50    6     2     3     3       0
# 5       0    8.50    2     0     1     0       0
# 0       0    7.75   10     5     0     0       0
# 1       0   12.00    1     4     0     0       0
# 2       0    8.52    6     4     0     0       0
# 3       3    7.25   10     3     1     0       0
# 4       1    5.25    8     1     0     0       0
# 5       0   12.00    4     2     2     0       0

# %%
batting = batting.set_index("name")
batting
# Out:
#              isNotOut                       out              team  \
# name
# Q de Kock       False          c Stokes b Gopal    Mumbai Indians
# RG Sharma       False                c  b Gopal    Mumbai Indians
# SA Yadav        False        c Kulkarni b Binny    Mumbai Indians
# HH Pandya       False              lbw b Archer    Mumbai Indians
# KA Pollard      False                 b Unadkat    Mumbai Indians
# BCJ Cutting      True                   not out    Mumbai Indians
# KH Pandya        True                   not out    Mumbai Indians
# AM Rahane       False          c Yadav b Chahar  Rajasthan Royals
# SV Samson       False        c Pollard b Chahar  Rajasthan Royals
# SPD Smith        True                   not out  Rajasthan Royals
# BA Stokes       False                  b Chahar  Rajasthan Royals
# R Parag         False  run out (Cutting/Pandya)  Rajasthan Royals
# AJ Turner       False              lbw b Bumrah  Rajasthan Royals
# STR Binny        True                   not out  Rajasthan Royals
#
#                      opponent runs balls mins fours sixes strikeRate
# name
# Q de Kock    Rajasthan Royals   65    47   74     6     2     138.29
# RG Sharma    Rajasthan Royals    5     7   13     1     0      71.42
# SA Yadav     Rajasthan Royals   34    33   58     1     1     103.03
# HH Pandya    Rajasthan Royals   23    15   37     2     1     153.33
# KA Pollard   Rajasthan Royals   10     7   16     0     1     142.85
# BCJ Cutting  Rajasthan Royals   13     9   20     1     1     144.44
# KH Pandya    Rajasthan Royals    2     2    4     0     0     100.00
# AM Rahane      Mumbai Indians   65    47   74     6     2     138.29
# SV Samson      Mumbai Indians    5     7   13     1     0      71.42
# SPD Smith      Mumbai Indians   34    33   58     1     1     103.03
# BA Stokes      Mumbai Indians   23    15   37     2     1     153.33
# R Parag        Mumbai Indians   10     7   16     0     1     142.85
# AJ Turner      Mumbai Indians   13     9   20     1     1     144.44
# STR Binny      Mumbai Indians    2     2    4     0     0     100.00

# %%
bowling = bowling.set_index("name")
bowling
# Out:
#                          team          opponent overs maidens conceded  \
# name
# STR Binny    Rajasthan Royals    Mumbai Indians     3       0       19
# DS Kulkarni  Rajasthan Royals    Mumbai Indians     3       0       31
# S Gopal      Rajasthan Royals    Mumbai Indians     4       0       21
# JC Archer    Rajasthan Royals    Mumbai Indians     4       0       22
# JD Unadkat   Rajasthan Royals    Mumbai Indians     4       0       46
# R Parag      Rajasthan Royals    Mumbai Indians     2       0       17
# HH Pandya      Mumbai Indians  Rajasthan Royals     4       0       31
# KH Pandya      Mumbai Indians  Rajasthan Royals     2       0       24
# SL Malinga     Mumbai Indians  Rajasthan Royals   3.1       0       27
# RD Chahar      Mumbai Indians  Rajasthan Royals     4       0       29
# JJ Bumrah      Mumbai Indians  Rajasthan Royals     4       0       21
# M Markande     Mumbai Indians  Rajasthan Royals     2       0       24
#
#             wickets economy dots fours sixes wides noballs
# name
# STR Binny         1    6.33    8     2     0     0       0
# DS Kulkarni       0   10.33    6     4     1     1       0
# S Gopal           2    5.25    8     1     0     0       0
# JC Archer         1    5.50   14     2     1     0       0
# JD Unadkat        1   11.50    6     2     3     3       0
# R Parag           0    8.50    2     0     1     0       0
# HH Pandya         0    7.75   10     5     0     0       0
# KH Pandya         0   12.00    1     4     0     0       0
# SL Malinga        0    8.52    6     4     0     0       0
# RD Chahar         3    7.25   10     3     1     0       0
# JJ Bumrah         1    5.25    8     1     0     0       0
# M Markande        0   12.00    4     2     2     0       0

# %%
players = {}
for (i, player) in enumerate(Match(match_id).team_1_players):
    short_name = player['mobile_name']
    full_name = player['card_long']
    players[short_name] = full_name
for (i, player) in enumerate(Match(match_id).team_2_players):
    short_name = player['mobile_name']
    full_name = player['card_long']
    players[short_name] = full_name

# %%
dismissals = batting['out'][batting['out'] != 'not out']

# %%
run_out_fielders = []
catch_fielders = []
stumping_wk = []

for d in dismissals:
    if ('run out' in d):
        player_short_name = d[d.find("(")+1:d.find(")")]
        if ("/" in player_short_name):
            player_short_name = player_short_name[0:player_short_name.find("/")]
        run_out_fielders.append(players[player_short_name])
    elif (d.startswith('c  b')):
        player_short_name = d.split(" ")[3]
        if ("/" in player_short_name):
            player_short_name = player_short_name[0:player_short_name.find("/")]
        catch_fielders.append(players[player_short_name])
    elif (d.startswith('c ')):
        player_short_name = d.split(" ")[1]
        if ("/" in player_short_name):
            player_short_name = player_short_name[0:player_short_name.find("/")]
        catch_fielders.append(players[player_short_name])
    elif (d.startswith('st ')):
        player_short_name = d.split(" ")[1]
        if (player_short_name.startswith("wk")):
            player_short_name = player_short_name[2:]
        stumping_wk.append(players[player_short_name])

# %%
fielding = pd.DataFrame()

for p in run_out_fielders:
    fielding = fielding.append(pd.Series([p, 'RunOut'], index=["Name","Type"]), ignore_index=True)
for p in catch_fielders:
    fielding = fielding.append(pd.Series([p, 'Catch'], index=["Name","Type"]), ignore_index=True)
for p in stumping_wk:
    fielding = fielding.append(pd.Series([p, 'Stumping'], index=["Name","Type"]), ignore_index=True)

fielding = fielding.set_index('Name')

# %% [markdown]
# Final Results :
#
# A. Batting

# %%
batting
# Out:
#              isNotOut                       out              team  \
# name
# Q de Kock       False          c Stokes b Gopal    Mumbai Indians
# RG Sharma       False                c  b Gopal    Mumbai Indians
# SA Yadav        False        c Kulkarni b Binny    Mumbai Indians
# HH Pandya       False              lbw b Archer    Mumbai Indians
# KA Pollard      False                 b Unadkat    Mumbai Indians
# BCJ Cutting      True                   not out    Mumbai Indians
# KH Pandya        True                   not out    Mumbai Indians
# AM Rahane       False          c Yadav b Chahar  Rajasthan Royals
# SV Samson       False        c Pollard b Chahar  Rajasthan Royals
# SPD Smith        True                   not out  Rajasthan Royals
# BA Stokes       False                  b Chahar  Rajasthan Royals
# R Parag         False  run out (Cutting/Pandya)  Rajasthan Royals
# AJ Turner       False              lbw b Bumrah  Rajasthan Royals
# STR Binny        True                   not out  Rajasthan Royals
#
#                      opponent runs balls mins fours sixes strikeRate
# name
# Q de Kock    Rajasthan Royals   65    47   74     6     2     138.29
# RG Sharma    Rajasthan Royals    5     7   13     1     0      71.42
# SA Yadav     Rajasthan Royals   34    33   58     1     1     103.03
# HH Pandya    Rajasthan Royals   23    15   37     2     1     153.33
# KA Pollard   Rajasthan Royals   10     7   16     0     1     142.85
# BCJ Cutting  Rajasthan Royals   13     9   20     1     1     144.44
# KH Pandya    Rajasthan Royals    2     2    4     0     0     100.00
# AM Rahane      Mumbai Indians   65    47   74     6     2     138.29
# SV Samson      Mumbai Indians    5     7   13     1     0      71.42
# SPD Smith      Mumbai Indians   34    33   58     1     1     103.03
# BA Stokes      Mumbai Indians   23    15   37     2     1     153.33
# R Parag        Mumbai Indians   10     7   16     0     1     142.85
# AJ Turner      Mumbai Indians   13     9   20     1     1     144.44
# STR Binny      Mumbai Indians    2     2    4     0     0     100.00

# %% [markdown]
# B. Bowling

# %%
bowling
# Out:
#                          team          opponent overs maidens conceded  \
# name
# STR Binny    Rajasthan Royals    Mumbai Indians     3       0       19
# DS Kulkarni  Rajasthan Royals    Mumbai Indians     3       0       31
# S Gopal      Rajasthan Royals    Mumbai Indians     4       0       21
# JC Archer    Rajasthan Royals    Mumbai Indians     4       0       22
# JD Unadkat   Rajasthan Royals    Mumbai Indians     4       0       46
# R Parag      Rajasthan Royals    Mumbai Indians     2       0       17
# HH Pandya      Mumbai Indians  Rajasthan Royals     4       0       31
# KH Pandya      Mumbai Indians  Rajasthan Royals     2       0       24
# SL Malinga     Mumbai Indians  Rajasthan Royals   3.1       0       27
# RD Chahar      Mumbai Indians  Rajasthan Royals     4       0       29
# JJ Bumrah      Mumbai Indians  Rajasthan Royals     4       0       21
# M Markande     Mumbai Indians  Rajasthan Royals     2       0       24
#
#             wickets economy dots fours sixes wides noballs
# name
# STR Binny         1    6.33    8     2     0     0       0
# DS Kulkarni       0   10.33    6     4     1     1       0
# S Gopal           2    5.25    8     1     0     0       0
# JC Archer         1    5.50   14     2     1     0       0
# JD Unadkat        1   11.50    6     2     3     3       0
# R Parag           0    8.50    2     0     1     0       0
# HH Pandya         0    7.75   10     5     0     0       0
# KH Pandya         0   12.00    1     4     0     0       0
# SL Malinga        0    8.52    6     4     0     0       0
# RD Chahar         3    7.25   10     3     1     0       0
# JJ Bumrah         1    5.25    8     1     0     0       0
# M Markande        0   12.00    4     2     2     0       0

# %% [markdown]
# C. Fielding

# %%
fielding
# Out:
#                Type
# Name
# BCJ Cutting  RunOut
# BA Stokes     Catch
# S Gopal       Catch
# DS Kulkarni   Catch
# SA Yadav      Catch
# KA Pollard    Catch

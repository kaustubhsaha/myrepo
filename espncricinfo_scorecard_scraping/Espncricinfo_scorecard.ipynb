# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# The next cell needs to be executed only once - the first time when you are running this on a particular host

# %%
# !pip install python-espncricinfo
# !pip install grequests
# !pip install pandas
# !pip install numpy

# %% [markdown]
# This will take a while:

# %%
from espncricinfo.summary import Summary
from espncricinfo.match import Match 
from espncricinfo.series import Series
from espncricinfo.exceptions import MatchNotFoundError, NoScorecardError

# %%
from bs4 import BeautifulSoup

# %%
import json
import requests

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Get a match id as import from user. Match id is a numeric value (e.g 1178415) used by espncricinfo as unique identifier for a match

# %%
match_id = input("Please enter match id :")
# Out:
# Please enter match id :1178415

# %% [markdown]
# Based on the match_id, generate the scorecard URL

# %%
url = Match(match_id).match_url
print("Will extract match details from ", url)
# Out:
# Will extract match details from  http://www.espncricinfo.com/matches/engine/match/1178415.html

# %%
match_html = Match(match_id).html

# %%
match_json = json.loads(match_html.find_all('script')[12].get_text().replace("\n", " ").replace('window.__INITIAL_STATE__ =','').replace('&dagger;','wk').replace('&amp;','').replace('wkts;','wkts,').replace('wkt;','wkt,').strip().replace('};', "}};").split('};')[0])

# %%
batting_innings_1 = pd.DataFrame(match_json['gamePackage']['scorecard']['innings']['1']['batsmen'])
batting_innings_1.head()
# Out:
#    captain                                         commentary  hasVideoId  \
# 0    False                                                          False
# 1    False  <strong>Has Rahane sold Samson down the river?...       False
# 2     True  <strong>there's the breakthrough</strong>! Len...       False
# 3    False  full ball, and he has muscled this towards lon...       False
# 4    False  <strong>GONE AGAIN!</strong> Slower ball, outs...       False
#
#                                                 href  isNotOut       name  \
# 0  http://www.espncricinfo.com/ci/content/player/...      True  AM Rahane
# 1  http://www.espncricinfo.com/ci/content/player/...     False  SV Samson
# 2  http://www.espncricinfo.com/ci/content/player/...     False  SPD Smith
# 3  http://www.espncricinfo.com/ci/content/player/...     False  BA Stokes
# 4  http://www.espncricinfo.com/ci/content/player/...     False  AJ Turner
#
#   roles      runningOver                 runningScore              shortText  \
# 0                     {}                           {}                not out
# 1    wk   {'overs': 1.1}    {'wickets': 1, 'runs': 5}       run out (Rabada)
# 2   (c)  {'overs': 13.1}  {'wickets': 2, 'runs': 135}       c Morris b Patel
# 3        {'overs': 15.5}  {'wickets': 3, 'runs': 157}        c Iyer b Morris
# 4        {'overs': 16.4}  {'wickets': 4, 'runs': 163}  c Rutherford b Sharma
#
#                                                stats  \
# 0  [{'name': 'runs', 'text': 'R', 'value': '105'}...
# 1  [{'name': 'runs', 'text': 'R', 'value': '0'}, ...
# 2  [{'name': 'runs', 'text': 'R', 'value': '50'},...
# 3  [{'name': 'runs', 'text': 'R', 'value': '8'}, ...
# 4  [{'name': 'runs', 'text': 'R', 'value': '0'}, ...
#
#                           trackingName
# 0  &lpos=cricket:game:scorecard:player
# 1  &lpos=cricket:game:scorecard:player
# 2  &lpos=cricket:game:scorecard:player
# 3  &lpos=cricket:game:scorecard:player
# 4  &lpos=cricket:game:scorecard:player

# %%
bat1_label = match_json['gamePackage']['scorecard']['innings']['1']['title']
bat1_label_splits = bat1_label.split(' ')
bat1_label_splits.pop()
bat1_team =  " ".join(bat1_label_splits)
print(bat1_team, "batted first")
# Out:
# Rajasthan Royals batted first

# %%
batting_innings_2 = pd.DataFrame(match_json['gamePackage']['scorecard']['innings']['2']['batsmen'])
batting_innings_2.head()
# Out:
#    captain                                         commentary  hasVideoId  \
# 0    False  tossed up, and he has played this towards long...       False
# 1    False  <strong>Shreyas places faith in the googly aga...       False
# 2     True  <strong>it's the old saying about adding two w...       False
# 3    False                                                          False
# 4    False  short, and he has looked to slice this towards...       False
#
#                                                 href  isNotOut           name  \
# 0  http://www.espncricinfo.com/ci/content/player/...     False        PP Shaw
# 1  http://www.espncricinfo.com/ci/content/player/...     False       S Dhawan
# 2  http://www.espncricinfo.com/ci/content/player/...     False        SS Iyer
# 3  http://www.espncricinfo.com/ci/content/player/...      True        RR Pant
# 4  http://www.espncricinfo.com/ci/content/player/...     False  SE Rutherford
#
#   roles      runningOver                 runningScore            shortText  \
# 0        {'overs': 16.4}  {'wickets': 3, 'runs': 161}      c Parag b Gopal
# 1         {'overs': 7.3}   {'wickets': 1, 'runs': 72}  st wkSamson b Gopal
# 2   (c)   {'overs': 8.5}   {'wickets': 2, 'runs': 77}     c Stokes b Parag
# 3    wk               {}                           {}              not out
# 4        {'overs': 17.6}  {'wickets': 4, 'runs': 175}   c Parag b Kulkarni
#
#                                                stats  \
# 0  [{'name': 'runs', 'text': 'R', 'value': '42'},...
# 1  [{'name': 'runs', 'text': 'R', 'value': '54'},...
# 2  [{'name': 'runs', 'text': 'R', 'value': '4'}, ...
# 3  [{'name': 'runs', 'text': 'R', 'value': '78'},...
# 4  [{'name': 'runs', 'text': 'R', 'value': '11'},...
#
#                           trackingName
# 0  &lpos=cricket:game:scorecard:player
# 1  &lpos=cricket:game:scorecard:player
# 2  &lpos=cricket:game:scorecard:player
# 3  &lpos=cricket:game:scorecard:player
# 4  &lpos=cricket:game:scorecard:player

# %%
bat2_label = match_json['gamePackage']['scorecard']['innings']['2']['title']
bat2_label_splits = bat2_label.split(' ')
bat2_label_splits.pop()
bat2_team =  " ".join(bat2_label_splits)
print(bat2_team, "batted second")
# Out:
# Delhi Capitals batted second

# %%
batting_innings_1['Team'] = bat1_team
batting_innings_1['Opponent'] = bat2_team
batting_innings_2['Team'] = bat2_team
batting_innings_2['Opponent'] = bat1_team

# %%
def flatten(js):
    return pd.DataFrame(js).set_index(['text','name']).squeeze()

# %% [markdown]
# Extract batting stats for batting innings 1

# %%
batting_innings_1_stats = batting_innings_1.stats.apply(flatten)
batting_innings_1_stats
# Out:
# text    R          B       M    4s    6s         SR
# name runs ballsFaced minutes fours sixes strikeRate
# 0     105         63     100    11     3     166.66
# 1       0          0       7     0     0          -
# 2      50         32      57     8     0     156.25
# 3       8          8      15     1     0     100.00
# 4       0          1       6     0     0       0.00
# 5      19         13      15     2     0     146.15
# 6       4          3       3     1     0     133.33

# %% [markdown]
# Extract batting stats for batting innings 2

# %%
batting_innings_2_stats = batting_innings_1.stats.apply(flatten)
batting_innings_2_stats
# Out:
# text    R          B       M    4s    6s         SR
# name runs ballsFaced minutes fours sixes strikeRate
# 0     105         63     100    11     3     166.66
# 1       0          0       7     0     0          -
# 2      50         32      57     8     0     156.25
# 3       8          8      15     1     0     100.00
# 4       0          1       6     0     0       0.00
# 5      19         13      15     2     0     146.15
# 6       4          3       3     1     0     133.33

# %%
def remove_extra_cols_bat(df):
    if df.columns.contains('captain'):
        df = df.drop(['captain','commentary','runningScore','runningOver', 'stats','hasVideoId','href','roles','trackingName'], axis=1)
    return df

# %%
batting_innings_1 = remove_extra_cols_bat(batting_innings_1)
batting_innings_2 = remove_extra_cols_bat(batting_innings_2)

# %%
batting_innings_1
# Out:
#    isNotOut       name              shortText              Team  \
# 0      True  AM Rahane                not out  Rajasthan Royals
# 1     False  SV Samson       run out (Rabada)  Rajasthan Royals
# 2     False  SPD Smith       c Morris b Patel  Rajasthan Royals
# 3     False  BA Stokes        c Iyer b Morris  Rajasthan Royals
# 4     False  AJ Turner  c Rutherford b Sharma  Rajasthan Royals
# 5     False  STR Binny               b Rabada  Rajasthan Royals
# 6     False    R Parag               b Rabada  Rajasthan Royals
#
#          Opponent
# 0  Delhi Capitals
# 1  Delhi Capitals
# 2  Delhi Capitals
# 3  Delhi Capitals
# 4  Delhi Capitals
# 5  Delhi Capitals
# 6  Delhi Capitals

# %%
batting_innings_2
# Out:
#    isNotOut           name            shortText            Team  \
# 0     False        PP Shaw      c Parag b Gopal  Delhi Capitals
# 1     False       S Dhawan  st wkSamson b Gopal  Delhi Capitals
# 2     False        SS Iyer     c Stokes b Parag  Delhi Capitals
# 3      True        RR Pant              not out  Delhi Capitals
# 4     False  SE Rutherford   c Parag b Kulkarni  Delhi Capitals
# 5      True      CA Ingram              not out  Delhi Capitals
#
#            Opponent
# 0  Rajasthan Royals
# 1  Rajasthan Royals
# 2  Rajasthan Royals
# 3  Rajasthan Royals
# 4  Rajasthan Royals
# 5  Rajasthan Royals

# %%
full_batting_innings_1 = pd.concat([batting_innings_1, batting_innings_1_stats], axis=1)
full_batting_innings_1 = full_batting_innings_1.dropna()
full_batting_innings_1
# Out:
#    isNotOut       name              shortText              Team  \
# 0      True  AM Rahane                not out  Rajasthan Royals
# 1     False  SV Samson       run out (Rabada)  Rajasthan Royals
# 2     False  SPD Smith       c Morris b Patel  Rajasthan Royals
# 3     False  BA Stokes        c Iyer b Morris  Rajasthan Royals
# 4     False  AJ Turner  c Rutherford b Sharma  Rajasthan Royals
# 5     False  STR Binny               b Rabada  Rajasthan Royals
# 6     False    R Parag               b Rabada  Rajasthan Royals
#
#          Opponent (R, runs) (B, ballsFaced) (M, minutes) (4s, fours)  \
# 0  Delhi Capitals       105              63          100          11
# 1  Delhi Capitals         0               0            7           0
# 2  Delhi Capitals        50              32           57           8
# 3  Delhi Capitals         8               8           15           1
# 4  Delhi Capitals         0               1            6           0
# 5  Delhi Capitals        19              13           15           2
# 6  Delhi Capitals         4               3            3           1
#
#   (6s, sixes) (SR, strikeRate)
# 0           3           166.66
# 1           0                -
# 2           0           156.25
# 3           0           100.00
# 4           0             0.00
# 5           0           146.15
# 6           0           133.33

# %%
full_batting_innings_2 = pd.concat([batting_innings_2, batting_innings_2_stats], axis=1)
full_batting_innings_2 = full_batting_innings_2.dropna()
full_batting_innings_2
# Out:
#   isNotOut           name            shortText            Team  \
# 0    False        PP Shaw      c Parag b Gopal  Delhi Capitals
# 1    False       S Dhawan  st wkSamson b Gopal  Delhi Capitals
# 2    False        SS Iyer     c Stokes b Parag  Delhi Capitals
# 3     True        RR Pant              not out  Delhi Capitals
# 4    False  SE Rutherford   c Parag b Kulkarni  Delhi Capitals
# 5     True      CA Ingram              not out  Delhi Capitals
#
#            Opponent (R, runs) (B, ballsFaced) (M, minutes) (4s, fours)  \
# 0  Rajasthan Royals       105              63          100          11
# 1  Rajasthan Royals         0               0            7           0
# 2  Rajasthan Royals        50              32           57           8
# 3  Rajasthan Royals         8               8           15           1
# 4  Rajasthan Royals         0               1            6           0
# 5  Rajasthan Royals        19              13           15           2
#
#   (6s, sixes) (SR, strikeRate)
# 0           3           166.66
# 1           0                -
# 2           0           156.25
# 3           0           100.00
# 4           0             0.00
# 5           0           146.15

# %%
batting = pd.concat([full_batting_innings_1, full_batting_innings_2], axis=0)
batting
# Out:
#   isNotOut           name              shortText              Team  \
# 0     True      AM Rahane                not out  Rajasthan Royals
# 1    False      SV Samson       run out (Rabada)  Rajasthan Royals
# 2    False      SPD Smith       c Morris b Patel  Rajasthan Royals
# 3    False      BA Stokes        c Iyer b Morris  Rajasthan Royals
# 4    False      AJ Turner  c Rutherford b Sharma  Rajasthan Royals
# 5    False      STR Binny               b Rabada  Rajasthan Royals
# 6    False        R Parag               b Rabada  Rajasthan Royals
# 0    False        PP Shaw        c Parag b Gopal    Delhi Capitals
# 1    False       S Dhawan    st wkSamson b Gopal    Delhi Capitals
# 2    False        SS Iyer       c Stokes b Parag    Delhi Capitals
# 3     True        RR Pant                not out    Delhi Capitals
# 4    False  SE Rutherford     c Parag b Kulkarni    Delhi Capitals
# 5     True      CA Ingram                not out    Delhi Capitals
#
#            Opponent (R, runs) (B, ballsFaced) (M, minutes) (4s, fours)  \
# 0    Delhi Capitals       105              63          100          11
# 1    Delhi Capitals         0               0            7           0
# 2    Delhi Capitals        50              32           57           8
# 3    Delhi Capitals         8               8           15           1
# 4    Delhi Capitals         0               1            6           0
# 5    Delhi Capitals        19              13           15           2
# 6    Delhi Capitals         4               3            3           1
# 0  Rajasthan Royals       105              63          100          11
# 1  Rajasthan Royals         0               0            7           0
# 2  Rajasthan Royals        50              32           57           8
# 3  Rajasthan Royals         8               8           15           1
# 4  Rajasthan Royals         0               1            6           0
# 5  Rajasthan Royals        19              13           15           2
#
#   (6s, sixes) (SR, strikeRate)
# 0           3           166.66
# 1           0                -
# 2           0           156.25
# 3           0           100.00
# 4           0             0.00
# 5           0           146.15
# 6           0           133.33
# 0           3           166.66
# 1           0                -
# 2           0           156.25
# 3           0           100.00
# 4           0             0.00
# 5           0           146.15

# %% [markdown]
# Tidy up the column names

# %%
batting.columns = ["isNotOut","name","out","team","opponent","runs","balls","mins","fours","sixes","strikeRate"]
batting
# Out:
#   isNotOut           name                    out              team  \
# 0     True      AM Rahane                not out  Rajasthan Royals
# 1    False      SV Samson       run out (Rabada)  Rajasthan Royals
# 2    False      SPD Smith       c Morris b Patel  Rajasthan Royals
# 3    False      BA Stokes        c Iyer b Morris  Rajasthan Royals
# 4    False      AJ Turner  c Rutherford b Sharma  Rajasthan Royals
# 5    False      STR Binny               b Rabada  Rajasthan Royals
# 6    False        R Parag               b Rabada  Rajasthan Royals
# 0    False        PP Shaw        c Parag b Gopal    Delhi Capitals
# 1    False       S Dhawan    st wkSamson b Gopal    Delhi Capitals
# 2    False        SS Iyer       c Stokes b Parag    Delhi Capitals
# 3     True        RR Pant                not out    Delhi Capitals
# 4    False  SE Rutherford     c Parag b Kulkarni    Delhi Capitals
# 5     True      CA Ingram                not out    Delhi Capitals
#
#            opponent runs balls mins fours sixes strikeRate
# 0    Delhi Capitals  105    63  100    11     3     166.66
# 1    Delhi Capitals    0     0    7     0     0          -
# 2    Delhi Capitals   50    32   57     8     0     156.25
# 3    Delhi Capitals    8     8   15     1     0     100.00
# 4    Delhi Capitals    0     1    6     0     0       0.00
# 5    Delhi Capitals   19    13   15     2     0     146.15
# 6    Delhi Capitals    4     3    3     1     0     133.33
# 0  Rajasthan Royals  105    63  100    11     3     166.66
# 1  Rajasthan Royals    0     0    7     0     0          -
# 2  Rajasthan Royals   50    32   57     8     0     156.25
# 3  Rajasthan Royals    8     8   15     1     0     100.00
# 4  Rajasthan Royals    0     1    6     0     0       0.00
# 5  Rajasthan Royals   19    13   15     2     0     146.15

# %%
bowling_innings_1 = pd.DataFrame(match_json['gamePackage']['scorecard']['innings']['1']['bowlers'])
bowling_innings_1
# Out:
#    captain  hasVideoId                                               href  \
# 0    False       False  http://www.espncricinfo.com/ci/content/player/...
# 1    False       False  http://www.espncricinfo.com/ci/content/player/...
# 2    False       False  http://www.espncricinfo.com/ci/content/player/...
# 3    False       False  http://www.espncricinfo.com/ci/content/player/...
# 4    False       False  http://www.espncricinfo.com/ci/content/player/...
# 5    False       False  http://www.espncricinfo.com/ci/content/player/...
#
#             name roles                                              stats  \
# 0       I Sharma        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 1       K Rabada        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 2       AR Patel        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 3       A Mishra        [{'name': 'overs', 'text': 'O', 'value': '3'},...
# 4      CH Morris        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 5  SE Rutherford        [{'name': 'overs', 'text': 'O', 'value': '1'},...
#
#                           trackingName
# 0  &lpos=cricket:game:scorecard:player
# 1  &lpos=cricket:game:scorecard:player
# 2  &lpos=cricket:game:scorecard:player
# 3  &lpos=cricket:game:scorecard:player
# 4  &lpos=cricket:game:scorecard:player
# 5  &lpos=cricket:game:scorecard:player

# %%
bowling_innings_2 = pd.DataFrame(match_json['gamePackage']['scorecard']['innings']['2']['bowlers'])
bowling_innings_2
# Out:
#    captain  hasVideoId                                               href  \
# 0    False       False  http://www.espncricinfo.com/ci/content/player/...
# 1    False       False  http://www.espncricinfo.com/ci/content/player/...
# 2    False       False  http://www.espncricinfo.com/ci/content/player/...
# 3    False       False  http://www.espncricinfo.com/ci/content/player/...
# 4    False       False  http://www.espncricinfo.com/ci/content/player/...
# 5    False       False  http://www.espncricinfo.com/ci/content/player/...
#
#           name roles                                              stats  \
# 0    STR Binny        [{'name': 'overs', 'text': 'O', 'value': '1'},...
# 1  DS Kulkarni        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 2   JD Unadkat        [{'name': 'overs', 'text': 'O', 'value': '3.2'...
# 3      S Gopal        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 4    JC Archer        [{'name': 'overs', 'text': 'O', 'value': '4'},...
# 5      R Parag        [{'name': 'overs', 'text': 'O', 'value': '3'},...
#
#                           trackingName
# 0  &lpos=cricket:game:scorecard:player
# 1  &lpos=cricket:game:scorecard:player
# 2  &lpos=cricket:game:scorecard:player
# 3  &lpos=cricket:game:scorecard:player
# 4  &lpos=cricket:game:scorecard:player
# 5  &lpos=cricket:game:scorecard:player

# %%
bowling_innings_1['Team'] = bat2_team
bowling_innings_1['Opponent'] = bat1_team
bowling_innings_2['Team'] = bat1_team
bowling_innings_2['Opponent'] = bat2_team

# %%
bowling_innings_1_stats = bowling_innings_1.stats.apply(flatten)
bowling_innings_1_stats
# Out:
# text     O       M        R       W        Econ   0s            4s  \
# name overs maidens conceded wickets economyRate dots foursConceded
# 0        4       0       29       1        7.25   12             4
# 1        4       0       37       2        9.25    8             4
# 2        4       0       39       1        9.75    5             4
# 3        3       0       28       0        9.33    3             3
# 4        4       0       41       1       10.25    6             5
# 5        1       0       16       0       16.00    1             3
#
# text            6s    WD      NB
# name sixesConceded wides noballs
# 0                0     0       0
# 1                1     1       0
# 2                1     0       0
# 3                0     0       0
# 4                1     1       0
# 5                0     2       0

# %%
bowling_innings_2_stats = bowling_innings_2.stats.apply(flatten)
bowling_innings_2_stats
# Out:
# text     O       M        R       W        Econ   0s            4s  \
# name overs maidens conceded wickets economyRate dots foursConceded
# 0        1       0        3       0        3.00    3             0
# 1        4       0       51       1       12.75    4             6
# 2      3.2       0       36       0       10.80    4             3
# 3        4       0       47       2       11.75    8             6
# 4        4       0       31       0        7.75    8             1
# 5        3       0       25       1        8.33    4             3
#
# text            6s    WD      NB
# name sixesConceded wides noballs
# 0                0     0       0
# 1                2     0       0
# 2                2     0       0
# 3                2     0       1
# 4                2     0       0
# 5                0     0       0

# %%
def remove_extra_cols_bowl(df):
    if df.columns.contains('captain'):
        df = df.drop(['captain','stats','hasVideoId','href','roles','trackingName'], axis=1)
    return df

# %%
bowling_innings_1 = remove_extra_cols_bowl(bowling_innings_1)
bowling_innings_2 = remove_extra_cols_bowl(bowling_innings_2)

# %%
bowling_innings_1
# Out:
#             name            Team          Opponent
# 0       I Sharma  Delhi Capitals  Rajasthan Royals
# 1       K Rabada  Delhi Capitals  Rajasthan Royals
# 2       AR Patel  Delhi Capitals  Rajasthan Royals
# 3       A Mishra  Delhi Capitals  Rajasthan Royals
# 4      CH Morris  Delhi Capitals  Rajasthan Royals
# 5  SE Rutherford  Delhi Capitals  Rajasthan Royals

# %%
bowling_innings_2
# Out:
#           name              Team        Opponent
# 0    STR Binny  Rajasthan Royals  Delhi Capitals
# 1  DS Kulkarni  Rajasthan Royals  Delhi Capitals
# 2   JD Unadkat  Rajasthan Royals  Delhi Capitals
# 3      S Gopal  Rajasthan Royals  Delhi Capitals
# 4    JC Archer  Rajasthan Royals  Delhi Capitals
# 5      R Parag  Rajasthan Royals  Delhi Capitals

# %%
full_bowling_innings_1 = pd.concat([bowling_innings_1, bowling_innings_1_stats], axis=1)
full_bowling_innings_1 = full_bowling_innings_1.dropna()
full_bowling_innings_1
# Out:
#             name            Team          Opponent (O, overs) (M, maidens)  \
# 0       I Sharma  Delhi Capitals  Rajasthan Royals          4            0
# 1       K Rabada  Delhi Capitals  Rajasthan Royals          4            0
# 2       AR Patel  Delhi Capitals  Rajasthan Royals          4            0
# 3       A Mishra  Delhi Capitals  Rajasthan Royals          3            0
# 4      CH Morris  Delhi Capitals  Rajasthan Royals          4            0
# 5  SE Rutherford  Delhi Capitals  Rajasthan Royals          1            0
#
#   (R, conceded) (W, wickets) (Econ, economyRate) (0s, dots)  \
# 0            29            1                7.25         12
# 1            37            2                9.25          8
# 2            39            1                9.75          5
# 3            28            0                9.33          3
# 4            41            1               10.25          6
# 5            16            0               16.00          1
#
#   (4s, foursConceded) (6s, sixesConceded) (WD, wides) (NB, noballs)
# 0                   4                   0           0             0
# 1                   4                   1           1             0
# 2                   4                   1           0             0
# 3                   3                   0           0             0
# 4                   5                   1           1             0
# 5                   3                   0           2             0

# %%
full_bowling_innings_2 = pd.concat([bowling_innings_2, bowling_innings_2_stats], axis=1)
full_bowling_innings_2 = full_bowling_innings_2.dropna()
full_bowling_innings_2
# Out:
#           name              Team        Opponent (O, overs) (M, maidens)  \
# 0    STR Binny  Rajasthan Royals  Delhi Capitals          1            0
# 1  DS Kulkarni  Rajasthan Royals  Delhi Capitals          4            0
# 2   JD Unadkat  Rajasthan Royals  Delhi Capitals        3.2            0
# 3      S Gopal  Rajasthan Royals  Delhi Capitals          4            0
# 4    JC Archer  Rajasthan Royals  Delhi Capitals          4            0
# 5      R Parag  Rajasthan Royals  Delhi Capitals          3            0
#
#   (R, conceded) (W, wickets) (Econ, economyRate) (0s, dots)  \
# 0             3            0                3.00          3
# 1            51            1               12.75          4
# 2            36            0               10.80          4
# 3            47            2               11.75          8
# 4            31            0                7.75          8
# 5            25            1                8.33          4
#
#   (4s, foursConceded) (6s, sixesConceded) (WD, wides) (NB, noballs)
# 0                   0                   0           0             0
# 1                   6                   2           0             0
# 2                   3                   2           0             0
# 3                   6                   2           0             1
# 4                   1                   2           0             0
# 5                   3                   0           0             0

# %%
bowling = pd.concat([full_bowling_innings_1, full_bowling_innings_2], axis=0)
bowling
# Out:
#             name              Team          Opponent (O, overs) (M, maidens)  \
# 0       I Sharma    Delhi Capitals  Rajasthan Royals          4            0
# 1       K Rabada    Delhi Capitals  Rajasthan Royals          4            0
# 2       AR Patel    Delhi Capitals  Rajasthan Royals          4            0
# 3       A Mishra    Delhi Capitals  Rajasthan Royals          3            0
# 4      CH Morris    Delhi Capitals  Rajasthan Royals          4            0
# 5  SE Rutherford    Delhi Capitals  Rajasthan Royals          1            0
# 0      STR Binny  Rajasthan Royals    Delhi Capitals          1            0
# 1    DS Kulkarni  Rajasthan Royals    Delhi Capitals          4            0
# 2     JD Unadkat  Rajasthan Royals    Delhi Capitals        3.2            0
# 3        S Gopal  Rajasthan Royals    Delhi Capitals          4            0
# 4      JC Archer  Rajasthan Royals    Delhi Capitals          4            0
# 5        R Parag  Rajasthan Royals    Delhi Capitals          3            0
#
#   (R, conceded) (W, wickets) (Econ, economyRate) (0s, dots)  \
# 0            29            1                7.25         12
# 1            37            2                9.25          8
# 2            39            1                9.75          5
# 3            28            0                9.33          3
# 4            41            1               10.25          6
# 5            16            0               16.00          1
# 0             3            0                3.00          3
# 1            51            1               12.75          4
# 2            36            0               10.80          4
# 3            47            2               11.75          8
# 4            31            0                7.75          8
# 5            25            1                8.33          4
#
#   (4s, foursConceded) (6s, sixesConceded) (WD, wides) (NB, noballs)
# 0                   4                   0           0             0
# 1                   4                   1           1             0
# 2                   4                   1           0             0
# 3                   3                   0           0             0
# 4                   5                   1           1             0
# 5                   3                   0           2             0
# 0                   0                   0           0             0
# 1                   6                   2           0             0
# 2                   3                   2           0             0
# 3                   6                   2           0             1
# 4                   1                   2           0             0
# 5                   3                   0           0             0

# %% [markdown]
# Tidy up the column names

# %%
bowling.columns = ['name','team','opponent','overs','maidens','conceded','wickets','economy','dots','fours','sixes','wides','noballs']
bowling
# Out:
#             name              team          opponent overs maidens conceded  \
# 0       I Sharma    Delhi Capitals  Rajasthan Royals     4       0       29
# 1       K Rabada    Delhi Capitals  Rajasthan Royals     4       0       37
# 2       AR Patel    Delhi Capitals  Rajasthan Royals     4       0       39
# 3       A Mishra    Delhi Capitals  Rajasthan Royals     3       0       28
# 4      CH Morris    Delhi Capitals  Rajasthan Royals     4       0       41
# 5  SE Rutherford    Delhi Capitals  Rajasthan Royals     1       0       16
# 0      STR Binny  Rajasthan Royals    Delhi Capitals     1       0        3
# 1    DS Kulkarni  Rajasthan Royals    Delhi Capitals     4       0       51
# 2     JD Unadkat  Rajasthan Royals    Delhi Capitals   3.2       0       36
# 3        S Gopal  Rajasthan Royals    Delhi Capitals     4       0       47
# 4      JC Archer  Rajasthan Royals    Delhi Capitals     4       0       31
# 5        R Parag  Rajasthan Royals    Delhi Capitals     3       0       25
#
#   wickets economy dots fours sixes wides noballs
# 0       1    7.25   12     4     0     0       0
# 1       2    9.25    8     4     1     1       0
# 2       1    9.75    5     4     1     0       0
# 3       0    9.33    3     3     0     0       0
# 4       1   10.25    6     5     1     1       0
# 5       0   16.00    1     3     0     2       0
# 0       0    3.00    3     0     0     0       0
# 1       1   12.75    4     6     2     0       0
# 2       0   10.80    4     3     2     0       0
# 3       2   11.75    8     6     2     0       1
# 4       0    7.75    8     1     2     0       0
# 5       1    8.33    4     3     0     0       0

# %%
batting = batting.set_index("name")
batting
# Out:
#               isNotOut                    out              team  \
# name
# AM Rahane         True                not out  Rajasthan Royals
# SV Samson        False       run out (Rabada)  Rajasthan Royals
# SPD Smith        False       c Morris b Patel  Rajasthan Royals
# BA Stokes        False        c Iyer b Morris  Rajasthan Royals
# AJ Turner        False  c Rutherford b Sharma  Rajasthan Royals
# STR Binny        False               b Rabada  Rajasthan Royals
# R Parag          False               b Rabada  Rajasthan Royals
# PP Shaw          False        c Parag b Gopal    Delhi Capitals
# S Dhawan         False    st wkSamson b Gopal    Delhi Capitals
# SS Iyer          False       c Stokes b Parag    Delhi Capitals
# RR Pant           True                not out    Delhi Capitals
# SE Rutherford    False     c Parag b Kulkarni    Delhi Capitals
# CA Ingram         True                not out    Delhi Capitals
#
#                        opponent runs balls mins fours sixes strikeRate
# name
# AM Rahane        Delhi Capitals  105    63  100    11     3     166.66
# SV Samson        Delhi Capitals    0     0    7     0     0          -
# SPD Smith        Delhi Capitals   50    32   57     8     0     156.25
# BA Stokes        Delhi Capitals    8     8   15     1     0     100.00
# AJ Turner        Delhi Capitals    0     1    6     0     0       0.00
# STR Binny        Delhi Capitals   19    13   15     2     0     146.15
# R Parag          Delhi Capitals    4     3    3     1     0     133.33
# PP Shaw        Rajasthan Royals  105    63  100    11     3     166.66
# S Dhawan       Rajasthan Royals    0     0    7     0     0          -
# SS Iyer        Rajasthan Royals   50    32   57     8     0     156.25
# RR Pant        Rajasthan Royals    8     8   15     1     0     100.00
# SE Rutherford  Rajasthan Royals    0     1    6     0     0       0.00
# CA Ingram      Rajasthan Royals   19    13   15     2     0     146.15

# %%
bowling = bowling.set_index("name")
bowling
# Out:
#                            team          opponent overs maidens conceded  \
# name
# I Sharma         Delhi Capitals  Rajasthan Royals     4       0       29
# K Rabada         Delhi Capitals  Rajasthan Royals     4       0       37
# AR Patel         Delhi Capitals  Rajasthan Royals     4       0       39
# A Mishra         Delhi Capitals  Rajasthan Royals     3       0       28
# CH Morris        Delhi Capitals  Rajasthan Royals     4       0       41
# SE Rutherford    Delhi Capitals  Rajasthan Royals     1       0       16
# STR Binny      Rajasthan Royals    Delhi Capitals     1       0        3
# DS Kulkarni    Rajasthan Royals    Delhi Capitals     4       0       51
# JD Unadkat     Rajasthan Royals    Delhi Capitals   3.2       0       36
# S Gopal        Rajasthan Royals    Delhi Capitals     4       0       47
# JC Archer      Rajasthan Royals    Delhi Capitals     4       0       31
# R Parag        Rajasthan Royals    Delhi Capitals     3       0       25
#
#               wickets economy dots fours sixes wides noballs
# name
# I Sharma            1    7.25   12     4     0     0       0
# K Rabada            2    9.25    8     4     1     1       0
# AR Patel            1    9.75    5     4     1     0       0
# A Mishra            0    9.33    3     3     0     0       0
# CH Morris           1   10.25    6     5     1     1       0
# SE Rutherford       0   16.00    1     3     0     2       0
# STR Binny           0    3.00    3     0     0     0       0
# DS Kulkarni         1   12.75    4     6     2     0       0
# JD Unadkat          0   10.80    4     3     2     0       0
# S Gopal             2   11.75    8     6     2     0       1
# JC Archer           0    7.75    8     1     2     0       0
# R Parag             1    8.33    4     3     0     0       0

# %%
players = {}
for (i, player) in enumerate(Match(match_id).team_1_players):
    short_name = player['card_short']
    full_name = player['card_long']
    players[short_name] = full_name
for (i, player) in enumerate(Match(match_id).team_2_players):
    short_name = player['card_short']
    full_name = player['card_long']
    players[short_name] = full_name

# %%
dismissals = batting['out'][batting['out'] != 'not out']

# %%
run_out_fielders = []
catch_fielders = []
stumping_wk = []

for d in dismissals:
    if ('run out' in d):
        player_short_name = d[d.find("(")+1:d.find(")")]
        run_out_fielders.append(players[player_short_name])
    elif (d.startswith('c ')):
        player_short_name = d.split(" ")[1]
        catch_fielders.append(players[player_short_name])
    elif (d.startswith('st ')):
        player_short_name = d.split(" ")[1]
        if (player_short_name.startswith("wk")):
            player_short_name = player_short_name[2:]
        stumping_wk.append(players[player_short_name])

# %%
fielding = pd.DataFrame()

for p in run_out_fielders:
    fielding = fielding.append(pd.Series([p, 'RunOut'], index=["Name","Type"]), ignore_index=True)
for p in catch_fielders:
    fielding = fielding.append(pd.Series([p, 'Catch'], index=["Name","Type"]), ignore_index=True)
for p in stumping_wk:
    fielding = fielding.append(pd.Series([p, 'Stumping'], index=["Name","Type"]), ignore_index=True)

fielding = fielding.set_index('Name')

# %% [markdown]
# Final Results :
#
# A. Batting

# %%
batting
# Out:
#               isNotOut                    out              team  \
# name
# AM Rahane         True                not out  Rajasthan Royals
# SV Samson        False       run out (Rabada)  Rajasthan Royals
# SPD Smith        False       c Morris b Patel  Rajasthan Royals
# BA Stokes        False        c Iyer b Morris  Rajasthan Royals
# AJ Turner        False  c Rutherford b Sharma  Rajasthan Royals
# STR Binny        False               b Rabada  Rajasthan Royals
# R Parag          False               b Rabada  Rajasthan Royals
# PP Shaw          False        c Parag b Gopal    Delhi Capitals
# S Dhawan         False    st wkSamson b Gopal    Delhi Capitals
# SS Iyer          False       c Stokes b Parag    Delhi Capitals
# RR Pant           True                not out    Delhi Capitals
# SE Rutherford    False     c Parag b Kulkarni    Delhi Capitals
# CA Ingram         True                not out    Delhi Capitals
#
#                        opponent runs balls mins fours sixes strikeRate
# name
# AM Rahane        Delhi Capitals  105    63  100    11     3     166.66
# SV Samson        Delhi Capitals    0     0    7     0     0          -
# SPD Smith        Delhi Capitals   50    32   57     8     0     156.25
# BA Stokes        Delhi Capitals    8     8   15     1     0     100.00
# AJ Turner        Delhi Capitals    0     1    6     0     0       0.00
# STR Binny        Delhi Capitals   19    13   15     2     0     146.15
# R Parag          Delhi Capitals    4     3    3     1     0     133.33
# PP Shaw        Rajasthan Royals  105    63  100    11     3     166.66
# S Dhawan       Rajasthan Royals    0     0    7     0     0          -
# SS Iyer        Rajasthan Royals   50    32   57     8     0     156.25
# RR Pant        Rajasthan Royals    8     8   15     1     0     100.00
# SE Rutherford  Rajasthan Royals    0     1    6     0     0       0.00
# CA Ingram      Rajasthan Royals   19    13   15     2     0     146.15

# %% [markdown]
# B. Bowling

# %%
bowling
# Out:
#                            team          opponent overs maidens conceded  \
# name
# I Sharma         Delhi Capitals  Rajasthan Royals     4       0       29
# K Rabada         Delhi Capitals  Rajasthan Royals     4       0       37
# AR Patel         Delhi Capitals  Rajasthan Royals     4       0       39
# A Mishra         Delhi Capitals  Rajasthan Royals     3       0       28
# CH Morris        Delhi Capitals  Rajasthan Royals     4       0       41
# SE Rutherford    Delhi Capitals  Rajasthan Royals     1       0       16
# STR Binny      Rajasthan Royals    Delhi Capitals     1       0        3
# DS Kulkarni    Rajasthan Royals    Delhi Capitals     4       0       51
# JD Unadkat     Rajasthan Royals    Delhi Capitals   3.2       0       36
# S Gopal        Rajasthan Royals    Delhi Capitals     4       0       47
# JC Archer      Rajasthan Royals    Delhi Capitals     4       0       31
# R Parag        Rajasthan Royals    Delhi Capitals     3       0       25
#
#               wickets economy dots fours sixes wides noballs
# name
# I Sharma            1    7.25   12     4     0     0       0
# K Rabada            2    9.25    8     4     1     1       0
# AR Patel            1    9.75    5     4     1     0       0
# A Mishra            0    9.33    3     3     0     0       0
# CH Morris           1   10.25    6     5     1     1       0
# SE Rutherford       0   16.00    1     3     0     2       0
# STR Binny           0    3.00    3     0     0     0       0
# DS Kulkarni         1   12.75    4     6     2     0       0
# JD Unadkat          0   10.80    4     3     2     0       0
# S Gopal             2   11.75    8     6     2     0       1
# JC Archer           0    7.75    8     1     2     0       0
# R Parag             1    8.33    4     3     0     0       0

# %% [markdown]
# C. Fielding

# %%
fielding
# Out:
#                    Type
# Name
# K Rabada         RunOut
# CH Morris         Catch
# SS Iyer           Catch
# SE Rutherford     Catch
# R Parag           Catch
# BA Stokes         Catch
# R Parag           Catch
# SV Samson      Stumping
